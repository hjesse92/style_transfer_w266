# %% [markdown]
# <a href="https://colab.research.google.com/github/hjesse92/style_transfer_w266/blob/main/Few_Shot_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Few Shot Learning

# %% [markdown]
# ## Setup

# %%
# !pip install -q transformers datasets sentencepiece rouge_score accelerate evaluate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 49.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 KB 21.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 KB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 25.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 105.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 25.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 68.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 31.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 17.7 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %%
#Am I running a GPU and what type is it?
# !nvidia-smi
# Out:
# Sat Apr  1 22:39:58 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch

# Clear out cuda
torch.cuda.empty_cache()

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('Number of GPU(s) available:', torch.cuda.device_count())
    print('GPU device name:', torch.cuda.get_device_name(0))

else:
    print('No GPU available')
    device = torch.device("cpu")
# Out:
# Number of GPU(s) available: 1
# GPU device name: Tesla T4

# %%
from logging import warning
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler, TensorDataset

from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, AdamW, Seq2SeqTrainingArguments, Seq2SeqTrainer


from sklearn.utils import resample
from sklearn.model_selection import train_test_split

import re
import random
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pprint
import nltk

import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/w266/style_transfer_w266/
# Out:
# /content/drive/MyDrive/w266/style_transfer_w266

# %%
# train_file = 'drive/MyDrive/data/original-train.tsv'
# dev_file = 'drive/MyDrive/data/original-dev.tsv'
# test_file = 'drive/MyDrive/data/original-test.tsv'
train_file = 'data/original-train.tsv'
dev_file = 'data/original-dev.tsv'
test_file = 'data/original-test.tsv'
df_train = pd.read_csv(train_file, sep='\t')
df_dev = pd.read_csv(dev_file, sep='\t')
df_test = pd.read_csv(test_file, sep='\t')

# %%
print(f'''mean length of offensive text: {df_train['offensive-text'].map(len).mean()}''')
print(f'''min length of offensive text: {df_train['offensive-text'].map(len).min()}''')
print(f'''max length of offensive text: {df_train['offensive-text'].map(len).max()}''')
print(f'''mean length of neutralized text: {df_train['style-transferred-text'].map(len).mean()}''')
print(f'''min length of neutralized text: {df_train['style-transferred-text'].map(len).min()}''')
print(f'''max length of neutralized text: {df_train['style-transferred-text'].map(len).max()}''')
# Out:
# mean length of offensive text: 69.85353535353535
# min length of offensive text: 9
# max length of offensive text: 238
# mean length of neutralized text: 60.48800505050505
# min length of neutralized text: 1
# max length of neutralized text: 174

# %% [markdown]
# # Trial with Flan T5

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

t5tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")
t5model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base", device_map="auto", torch_dtype=torch.float16)
# Out:
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
#@title 3-Shot Learning
df_fewshot = df_test.copy()
n_shots = 3

for row in range(len(df_fewshot)):
    #For each item in the test set, we use 3 examples from the training set to as n-shots
    sources_targets = df_train.sample(n_shots, replace=False)

    for i in range(n_shots):
        df_fewshot.loc[row, f'shot{i+1}_source'] = sources_targets.iloc[i,0]
        df_fewshot.loc[row, f'shot{i+1}_target'] = sources_targets.iloc[i,1]


df_fewshot = df_fewshot.rename(columns={'offensive-text':'source', 'style-transferred-text':'target'})

# %%
df_fewshot['prompt'] = df_fewshot.apply(lambda x: 
                 'Rewrite the toxic text in non-toxic style. \n\n'
                 'Toxic text: ' + x['shot1_source'] + '\n' + 'Non-toxic text: ' + x['shot1_target'] + '\n\n' + \
                 'Toxic text: ' + x['shot2_source'] + '\n' + 'Non-toxic text: ' + x['shot2_target'] + '\n\n' + \
                 'Toxic text: ' + x['shot3_source'] + '\n' + 'Non-toxic text: ' + x['shot3_target'] + '\n\n' + \
                 'Toxic text: ' + x['source'] + '\n' + 'Non-toxic text: ', axis=1)

# %%
print(df_fewshot.prompt[0])
# Out:
# Rewrite the toxic text in non-toxic style.
#
# Toxic text: Has been a US military puppet from jump
# Non-toxic text: Has been a tool for the US military from the beginning
#
# Toxic text: It's not though you fucking idiot
# Non-toxic text: It's not though
#
# Toxic text: Maybe you shouldn't turn your new country into the shithole you just left.
# Non-toxic text: You should be careful not to bring your old problems from your old country to your new country.
#
# Toxic text: So maybe you should be more retarded.
# Non-toxic text:

# %%
for i in range(len(df_fewshot)):
    if i%10 == 0:
        print(f'Working on number: {i}')
    t5_inputs = t5tokenizer([df_fewshot.prompt[i]], return_tensors='pt').input_ids.to("cuda")
    t5_summary_ids = t5model.generate(t5_inputs, 
                                    num_beams=5,
                                    no_repeat_ngram_size=1,
                                    num_return_sequences=1,
                                    top_p = 0.92,
                                    top_k = 100,
                                    min_length = 1,
                                    max_length = 200,
                                    do_sample=True,
                                    )
    output = t5tokenizer.batch_decode(t5_summary_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
    df_fewshot.loc[i,'fewshot_output'] = output
# Out:
# Working on number: 0
# Working on number: 10
# Working on number: 20
# Working on number: 30
# Working on number: 40
# Working on number: 50
# Working on number: 60
# Working on number: 70
# Working on number: 80
# Working on number: 90
# Working on number: 100
# Working on number: 110
# Working on number: 120
# Working on number: 130
# Working on number: 140
# Working on number: 150
# Working on number: 160
# Working on number: 170
# Working on number: 180
# Working on number: 190

# %%
df_fewshot.loc[:,['source','target','prompt','fewshot_output']]
# Out:
#                                                 source  \
# 0                So maybe you should be more retarded.
# 1    THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                        the fuck.... you are on drugs
# 3    NTA.   Dump his ass. Tablemanners are no rocke...
# 4                              Youre soft as baby shit
# ..                                                 ...
# 194  NTA, Jes-us your brother is dumb. How long did...
# 195  Formula one…nascar….shit it exactly the same e...
# 196  BRB, gonna go call the mods pathetic egotistic...
# 197                       CUCKOLD Carlson is a problem
# 198                I think you need to check your head
#
#                                                 target  \
# 0                 So maybe you should be more backward
# 1    THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                  uh..... you are not being realistic
# 3    You should leave him. Tablemanners are no rock...
# 4                                    Youre really soft
# ..                                                 ...
# 194  NTA, your brother is not thinking straight. Ho...
# 195  Formula one…nascar….it exactly the same except...
# 196                       BRB, gonna go call the mods.
# 197                             Carlson is the problem
# 198                 I think you need to check yourself
#
#                                                 prompt  \
# 0    Rewrite the toxic text in non-toxic style. \n\...
# 1    Rewrite the toxic text in non-toxic style. \n\...
# 2    Rewrite the toxic text in non-toxic style. \n\...
# 3    Rewrite the toxic text in non-toxic style. \n\...
# 4    Rewrite the toxic text in non-toxic style. \n\...
# ..                                                 ...
# 194  Rewrite the toxic text in non-toxic style. \n\...
# 195  Rewrite the toxic text in non-toxic style. \n\...
# 196  Rewrite the toxic text in non-toxic style. \n\...
# 197  Rewrite the toxic text in non-toxic style. \n\...
# 198  Rewrite the toxic text in non-toxic style. \n\...
#
#                                         fewshot_output
# 0                         You should be more retarded.
# 1    THERE IS A MEGATHREAD FOR VACCINE OR COVIDE RE...
# 2                        the fuck.... you are on drugs
# 3    Tablemanners are no rocket science. Treating o...
# 4                            You're soft as baby shit.
# ..                                                 ...
# 194  Jes-us your brother is dumb. How long did he t...
# 195  Formula one...nascar....shit it exactly the sa...
# 196     BRB, gonna go call the mods stupid neck beard.
# 197                              Carlson is a problem.
# 198               I think you need to check your head.
#
# [199 rows x 4 columns]

# %%
# df_fewshot.to_csv('test_output.csv',sep='\t',index=False)
df_fewshot.to_csv('outputs/t5_few_shot_output.csv',sep='\t',index=False)

# %% [markdown]
# ## Evaluation with ROUGE

# %%
import evaluate

rouge = evaluate.load('rouge')
bleu = evaluate.load('bleu')
# bleurt = evaluate.load('bleurt')
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]

# %%
#@title Baseline Score on the source and target
print(rouge.compute(predictions=df_fewshot.source,
              references=df_fewshot.target))
print(bleu.compute(predictions=df_fewshot.source,
              references=df_fewshot.target))

# If my predictions did nothing but repeat the same toxic text, I'd get these scores
# Out:
# {'rouge1': 0.6887918451280337, 'rouge2': 0.5605071385408666, 'rougeL': 0.6829326508983988, 'rougeLsum': 0.6845511504130748}
# {'bleu': 0.5391232310503405, 'precisions': [0.6839945280437757, 0.5702752293577982, 0.49604117181314333, 0.436613665663945], 'brevity_penalty': 1.0, 'length_ratio': 1.1498230436492332, 'translation_length': 2924, 'reference_length': 2543}

# %%
#@title Score after few shot learning
print(rouge.compute(predictions=df_fewshot.fewshot_output,
              references=df_fewshot.target))
print(bleu.compute(predictions=df_fewshot.fewshot_output,
              references=df_fewshot.target))
# Out:
# {'rouge1': 0.6416778124372912, 'rouge2': 0.49360163541682245, 'rougeL': 0.633482217077764, 'rougeLsum': 0.6344573837972729}
# {'bleu': 0.446899836804514, 'precisions': [0.6404580152671756, 0.4878149524989674, 0.39693969396939693, 0.32164031620553357], 'brevity_penalty': 1.0, 'length_ratio': 1.0302791977978765, 'translation_length': 2620, 'reference_length': 2543}

# %% [markdown]
# ## Evaluate with Classification Model - NonToxicScore

# %%
import sys
sys.path.append('./notebooks')
from DistilBertClassification import BertClassificationML, NonToxicScoreDataLoader, NonToxicScore

# Load DistilBERT Classification Model to calculate NonToxicScore
score_model = BertClassificationML()
score_model = score_model.to(device)

# Load training weights
pretrained_weights = torch.load('models/DistilBertToxicClassification7.pth')
score_model.load_state_dict(pretrained_weights )
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_transform.weight', 'vocab_projector.weight', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <All keys matched successfully>

# %%
output_file = 'outputs/t5_few_shot_output.csv'
output_col = 'fewshot_output'

# Create Data Loader
score_loader = NonToxicScoreDataLoader(output_file, output_col, max_length=512)

# Calculate NonToxicScore
fewshot_NonToxicScores, avg_score = NonToxicScore(score_loader, score_model)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# {'NonToxicScore': 0.25788199206364887}

# %%
# Look at output texts with low NonToxicScore, or still classified as Toxic after Style Transfering
df_fewshot = pd.read_csv('outputs/t5_few_shot_output.csv',sep='\t')
df_fewshot['NonToxicScore'] = fewshot_NonToxicScores

df_fewshot_lowscore = df_fewshot[df_fewshot['NonToxicScore'] < 0.5][['source', 'target', 'fewshot_output', 'NonToxicScore']]
df_fewshot_lowscore
# Out:
#                                                 source  \
# 0                So maybe you should be more retarded.
# 1    THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                        the fuck.... you are on drugs
# 4                              Youre soft as baby shit
# 6    And “poor kids are just as bright as white kid...
# ..                                                 ...
# 193  Didn't Trump tell that bitch off in an intervi...
# 194  NTA, Jes-us your brother is dumb. How long did...
# 195  Formula one…nascar….shit it exactly the same e...
# 196  BRB, gonna go call the mods pathetic egotistic...
# 198                I think you need to check your head
#
#                                                 target  \
# 0                 So maybe you should be more backward
# 1    THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                  uh..... you are not being realistic
# 4                                    Youre really soft
# 6    He said "poor kids are just as bright as white...
# ..                                                 ...
# 193  Didn't Trump tell her off in an interview not ...
# 194  NTA, your brother is not thinking straight. Ho...
# 195  Formula one…nascar….it exactly the same except...
# 196                       BRB, gonna go call the mods.
# 198                 I think you need to check yourself
#
#                                         fewshot_output  NonToxicScore
# 0                         You should be more retarded.       0.012004
# 1    THERE IS A MEGATHREAD FOR VACCINE OR COVIDE RE...       0.001306
# 2                        the fuck.... you are on drugs       0.001292
# 4                            You're soft as baby shit.       0.002777
# 6    And “poor kids are just as bright and white”.....       0.027229
# ..                                                 ...            ...
# 193  Didn't Trump tell that bitch off in an intervi...       0.001542
# 194  Jes-us your brother is dumb. How long did he t...       0.005284
# 195  Formula one...nascar....shit it exactly the sa...       0.013496
# 196     BRB, gonna go call the mods stupid neck beard.       0.002186
# 198               I think you need to check your head.       0.334959
#
# [148 rows x 4 columns]

# %% [markdown]
# # Tune the model with training set, then do few-shot learning again

# %% [markdown]
# ## Normal Training (no Trainer)

# %%
from datasets import load_metric, load_dataset

# %%
class ToxicData(Dataset):
    def __init__(self, data, tokenizer):
        super(Dataset, self).__init__()
        self.source_texts = 'transfer to nontoxic text: ' + data['offensive-text']
        self.target_texts = data['style-transferred-text']
        self.tokenizer=tokenizer

    def __len__(self):
        return len(self.target_texts)

    def __getitem__(self, idx):
        source_text = self.source_texts[idx]
        target_text = self.target_texts[idx]

        source_tokens = self.tokenizer.encode(source_text, padding='max_length',truncation=True)
        source_tensor = torch.tensor(source_tokens, dtype=torch.long)

        target_tokens = self.tokenizer.encode(target_text, padding='max_length',truncation=True)
        target_tensor = torch.tensor(target_tokens, dtype=torch.long)

        # # important: we need to replace the index of the padding tokens by -100
        # # such that they are not taken into account by the CrossEntropyLoss
        # labels_with_ignore_index = []
        # for labels_example in target_tokens.input_ids:
        #   labels_example = [label if label != 0 else -100 for label in labels_example]
        #   labels_with_ignore_index.append(labels_example)
        
        # source_tokens["labels"] = labels_with_ignore_index

        if torch.cuda.is_available():
            source_tensor = source_tensor.cuda()
            target_tensor = target_tensor.cuda()

        return source_tensor, target_tensor

# %%
train_file = 'data/original-train.tsv'
dev_file = 'data/original-dev.tsv'
test_file = 'data/original-test.tsv'

# %%
dataset = load_dataset('csv', sep="\t", data_files={'train': train_file, 'validation': dev_file,'test': test_file})
# Out:
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-d836ef9b772838ed/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-d836ef9b772838ed/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
train_ds = dataset['train']
val_ds = dataset['validation']
test_ds = dataset['test']

# %%
train_ds
# Out:
# Dataset({
#     features: ['offensive-text', 'style-transferred-text'],
#     num_rows: 1584
# })

# %%
example = train_ds[0]
org = example['offensive-text']
mod = example['style-transferred-text']
print("Original Text:", org)
print("Style Transfered Text:", mod)
# Out:
# Original Text: Pussy nobody asked for your input.
# Style Transfered Text: Nobody asked for your input

# %%
prefix = 'transfer to nontoxic text: '
max_input_length = 64
max_target_length = 64

def preprocess_examples(examples):
  # encode the documents
  orgs = examples['offensive-text']
  mods = examples['style-transferred-text']
  
  inputs = [prefix + org for org in orgs]
  model_inputs = t5tokenizer(inputs, max_length=max_input_length, padding="max_length", truncation=True)

  # encode the summaries
  labels = t5tokenizer(mods, max_length=max_target_length, padding="max_length", truncation=True).input_ids

  # important: we need to replace the index of the padding tokens by -100
  # such that they are not taken into account by the CrossEntropyLoss
  labels_with_ignore_index = []
  for labels_example in labels:
    labels_example = [label if label != 0 else -100 for label in labels_example]
    labels_with_ignore_index.append(labels_example)
  
  model_inputs["labels"] = labels_with_ignore_index

  return model_inputs

# %%
encoded_train_ds = train_ds.map(preprocess_examples, batched=True, remove_columns=train_ds.column_names)
encoded_val_ds = val_ds.map(preprocess_examples, batched=True, remove_columns=val_ds.column_names)
encoded_test_ds = test_ds.map(preprocess_examples, batched=True, remove_columns=test_ds.column_names)
# Out:
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d836ef9b772838ed/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-05ad685e6b095072.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d836ef9b772838ed/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-a579cd8ff985ae8d.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-d836ef9b772838ed/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-545df67969f696ec.arrow

# %%
t5tokenizer.decode(encoded_train_ds[0]['input_ids'])
# Out:
# 'transfer to nontoxic text: Pussy nobody asked for your input.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %%
labels = encoded_train_ds[0]['labels']
print(labels)
# Out:
# [22009, 1380, 21, 39, 3785, 1, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100]

# %%
t5tokenizer.decode([x for x in labels if x != -100])
# Out:
# 'Nobody asked for your input</s>'

# %%
encoded_train_ds.set_format(type="torch")
encoded_val_ds.set_format(type="torch")
encoded_test_ds.set_format(type="torch")

# %%
def create_dataloaders(train_batch_size=8, eval_batch_size=32):
    train_dataloader = DataLoader(encoded_train_ds, shuffle=True, batch_size=train_batch_size)
    val_dataloader = DataLoader(encoded_val_ds, shuffle=False, batch_size=eval_batch_size)
    
    return train_dataloader, val_dataloader

# %%
test_dataloader = DataLoader(encoded_test_ds, shuffle=False, batch_size=8)

# %%
hyperparameters = {
    "learning_rate": 2e-5,
    "num_epochs": 4, # set to very high number
    "train_batch_size": 8, # Actual batch size will this x 8 
    "eval_batch_size": 8, # Actual batch size will this x 8 
    "seed": 42,
    "patience": 3, # early stopping
    "output_dir": "/models/",
}

# %%
from transformers import T5ForConditionalGeneration, AdamW, set_seed
from accelerate import Accelerator
from tqdm.notebook import tqdm
import datasets
import transformers

def training_function():
    # Initialize accelerator
    accelerator = Accelerator()

    # To have only one message (and not 8) per logs of Transformers or Datasets, we set the logging verbosity
    # to INFO for the main process only.
    if accelerator.is_main_process:
        datasets.utils.logging.set_verbosity_warning()
        transformers.utils.logging.set_verbosity_info()
    else:
        datasets.utils.logging.set_verbosity_error()
        transformers.utils.logging.set_verbosity_error()

    # The seed need to be set before we instantiate the model, as it will determine the random head.
    set_seed(hyperparameters["seed"])

    # Instantiate the model, let Accelerate handle the device placement.
    model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")
    model = model.to(device)

    # Instantiate optimizer
    optimizer = AdamW(model.parameters(), lr=hyperparameters["learning_rate"])

    # Prepare everything
    train_dataloader, val_dataloader = create_dataloaders(
        train_batch_size=hyperparameters["train_batch_size"], eval_batch_size=hyperparameters["eval_batch_size"]
    )
    # unpack the objects in the same order we gave them to the prepare method.
    model, optimizer, train_dataloader, val_dataloader = accelerator.prepare(model, optimizer, 
                                                                             train_dataloader, val_dataloader)
    # train the model
    epochs_no_improve = 0
    min_val_loss = 1000000
    
    for epoch in range(hyperparameters["num_epochs"]):
        # We only enable the progress bar on the main process to avoid having 8 progress bars.
        progress_bar = tqdm(range(len(train_dataloader)), disable=not accelerator.is_main_process)
        progress_bar.set_description(f"Epoch: {epoch}")
        model.train()
        for batch in train_dataloader:
            outputs = model(**batch)
            loss = outputs.loss
            accelerator.backward(loss)
            
            optimizer.step()
            optimizer.zero_grad()
            progress_bar.set_postfix({'loss': loss.item()})
            progress_bar.update(1)

        # Evaluate at the end of the epoch (distributed evaluation as we have 8 TPU cores)
        model.eval()
        validation_losses = []
        for batch in val_dataloader:
            with torch.no_grad():
                outputs = model(**batch)
            loss = outputs.loss

            # We gather the loss from the 8 TPU cores to have them all.
            validation_losses.append(accelerator.gather(loss[None]))

        # Compute average validation loss
        val_loss = torch.stack(validation_losses).sum().item() / len(validation_losses)
        # Use accelerator.print to print only on the main process.
        accelerator.print(f"epoch {epoch}: validation loss:", val_loss)
        if val_loss < min_val_loss:
          epochs_no_improve = 0
          min_val_loss = val_loss

    return model

# %%
model = training_function()
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--google--flan-t5-base/snapshots/c782cba52f8ea6a704240578055cf1c3fc2f2ca9/config.json
# Model config T5Config {
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "tie_word_embeddings": false,
#   "transformers_version": "4.27.1",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--google--flan-t5-base/snapshots/c782cba52f8ea6a704240578055cf1c3fc2f2ca9/pytorch_model.bin
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.1"
# }
#
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at google/flan-t5-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--google--flan-t5-base/snapshots/c782cba52f8ea6a704240578055cf1c3fc2f2ca9/generation_config.json
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.27.1"
# }
#   0%|          | 0/198 [00:00<?, ?it/s]
# epoch 0: validation loss: 1.0558067321777345
#   0%|          | 0/198 [00:00<?, ?it/s]
# epoch 1: validation loss: 1.021386947631836
#   0%|          | 0/198 [00:00<?, ?it/s]
# epoch 2: validation loss: 1.0070569610595703
#   0%|          | 0/198 [00:00<?, ?it/s]
# epoch 3: validation loss: 0.9924876403808593

# %%
# from accelerate import notebook_launcher
# notebook_launcher(training_function)

# %%
# save training weights
torch.save(model.state_dict(), 'models/t5-detoxify-base1.pth')

# %% [markdown]
# ## Train T5 with Trainer

# %%
prefix = 'transfer to nontoxic text: '
max_input_length = 64
max_target_length = 64

def clean_text(text):
  sentences = nltk.sent_tokenize(text.strip())
  sentences_cleaned = [s for sent in sentences for s in sent.split("\n")]
  # sentences_cleaned_no_titles = [sent for sent in sentences_cleaned
  #                                if len(sent) > 0 and
  #                                sent[-1] in string.punctuation]
  # text_cleaned = "\n".join(sentences_cleaned_no_titles)
  text_cleaned = "\n".join(sentences_cleaned)
  return text_cleaned

def preprocess_data(examples):
#   texts_cleaned = [clean_text(text) for text in examples["text"]]
  source_inputs = [prefix + text for text in examples['offensive-text']]
  model_inputs = t5tokenizer(source_inputs, max_length=max_input_length, padding="max_length", truncation=True)
  
  target_inputs = [text for text in examples['style-transferred-text']]
  target_tokens = t5tokenizer(target_inputs, max_length=max_target_length, padding="max_length", truncation=True)
  
  # important: we need to replace the index of the padding tokens by -100
  # such that they are not taken into account by the CrossEntropyLoss
  labels_with_ignore_index = []
  for labels_example in target_tokens.input_ids:
    labels_example = [label if label != 0 else -100 for label in labels_example]
    labels_with_ignore_index.append(labels_example)
  
  model_inputs["labels"] = labels_with_ignore_index
  # model_inputs["labels"] = target_tokens
  
  return model_inputs

# %%
tokenized_datasets = dataset.map(preprocess_data, batched=True)
encoded_train_ds = dataset['train'].map(preprocess_data, batched=True, remove_columns=dataset['train'].column_names)
encoded_val_ds = dataset['validation'].map(preprocess_data, batched=True, remove_columns=dataset['validation'].column_names)
encoded_test_ds = dataset['test'].map(preprocess_data, batched=True, remove_columns=dataset['test'].column_names)
# Out:
# Map:   0%|          | 0/1584 [00:00<?, ? examples/s]
# Map:   0%|          | 0/198 [00:00<?, ? examples/s]
# Map:   0%|          | 0/199 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1584 [00:00<?, ? examples/s]
# Map:   0%|          | 0/198 [00:00<?, ? examples/s]
# Map:   0%|          | 0/199 [00:00<?, ? examples/s]

# %%
# preprocess_data(dataset['train'][0])
# tokenized_datasets['train']['input_ids'][0][0]
t5tokenizer.decode(tokenized_datasets['train'][0]['input_ids'])
# Out:
# 'transfer to nontoxic text: Pussy nobody asked for your input.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %%
t5tokenizer.decode(encoded_train_ds[0]['input_ids'])
# Out:
# 'transfer to nontoxic text: Pussy nobody asked for your input.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['offensive-text', 'style-transferred-text', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1584
#     })
#     validation: Dataset({
#         features: ['offensive-text', 'style-transferred-text', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 198
#     })
#     test: Dataset({
#         features: ['offensive-text', 'style-transferred-text', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 199
#     })
# })

# %%
encoded_train_ds

# %%
batch_size = 8
model_name = "google/flan-t5-base-tuned-toxicity"
model_dir = f"models/{model_name}"

args = Seq2SeqTrainingArguments(
    model_dir,
    evaluation_strategy="epoch",
    logging_strategy="epoch",
    save_strategy="epoch",
    # evaluation_strategy="steps",
    # eval_steps=100,
    # logging_strategy="steps",
    # logging_steps=100,
    # save_strategy="steps",
    # save_steps=200,
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    # save_total_limit=3,
    num_train_epochs=7,
    predict_with_generate=True,
    # fp16=True,
    load_best_model_at_end=True,
    metric_for_best_model="rouge1",
    # report_to="tensorboard",
    remove_unused_columns=False
)

# %%
data_collator = DataCollatorForSeq2Seq(t5tokenizer)
metric = load_metric("rouge")
# Out:
# Downloading builder script:   0%|          | 0.00/2.17k [00:00<?, ?B/s]

# %%
import nltk

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = t5tokenizer.batch_decode(predictions, skip_special_tokens=True)
    
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, t5tokenizer.pad_token_id)
    decoded_labels = t5tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip()))
                      for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) 
                      for label in decoded_labels]
    
    # Compute ROUGE scores
    result = metric.compute(predictions=decoded_preds, references=decoded_labels,
                            use_stemmer=True)

    # Extract ROUGE f1 scores
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length to metrics
    prediction_lens = [np.count_nonzero(pred != t5tokenizer.pad_token_id)
                      for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
from transformers import AdamW, get_cosine_schedule_with_warmup

t5model = T5ForConditionalGeneration.from_pretrained(model_ckpt)
t5model = t5model.to(device)

optimizer = AdamW(t5model.parameters(), lr=2e-5)
scheduler = get_cosine_schedule_with_warmup(optimizer, num_warmup_steps=10, num_training_steps=1000)
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

# %%
model_ckpt = "google/flan-t5-base"
def model_init():
    return AutoModelForSeq2SeqLM.from_pretrained(model_ckpt, return_dict=True)

trainer = Seq2SeqTrainer(
    # model_init=model_init,
    model=t5model,
    args=args,
    # train_dataset=tokenized_datasets['train'],
    train_dataset=encoded_train_ds, 
    # eval_dataset=tokenized_datasets['validation'],
    eval_dataset=encoded_val_ds,
    data_collator=data_collator,
    tokenizer=t5tokenizer,
    optimizers=(optimizer, scheduler),
    compute_metrics=compute_metrics
)

# %%
# %load_ext tensorboard
# %tensorboard --logdir '{model_dir}'/runs

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='1387' max='1386' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1386/1386 14:30, Epoch 7/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.271900</td>
#       <td>1.075335</td>
#       <td>66.937800</td>
#       <td>53.924800</td>
#       <td>66.826400</td>
#       <td>66.839700</td>
#       <td>16.262600</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.105600</td>
#       <td>1.038640</td>
#       <td>67.771300</td>
#       <td>54.549400</td>
#       <td>67.534200</td>
#       <td>67.488700</td>
#       <td>15.994900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.038300</td>
#       <td>1.020302</td>
#       <td>68.550700</td>
#       <td>55.503900</td>
#       <td>68.421300</td>
#       <td>68.402700</td>
#       <td>15.868700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.009200</td>
#       <td>1.017749</td>
#       <td>68.340200</td>
#       <td>55.432200</td>
#       <td>68.186700</td>
#       <td>68.147300</td>
#       <td>15.833300</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.002400</td>
#       <td>1.016863</td>
#       <td>68.070700</td>
#       <td>55.278900</td>
#       <td>67.873900</td>
#       <td>67.951600</td>
#       <td>15.848500</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.989500</td>
#       <td>1.017735</td>
#       <td>68.233600</td>
#       <td>55.362800</td>
#       <td>68.034400</td>
#       <td>68.118500</td>
#       <td>15.823200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.984800</td>
#       <td>1.013406</td>
#       <td>68.084900</td>
#       <td>55.497200</td>
#       <td>67.926500</td>
#       <td>67.993100</td>
#       <td>15.818200</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1386' max='1386' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1386/1386 15:29, Epoch 7/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.271900</td>
#       <td>1.075335</td>
#       <td>66.937800</td>
#       <td>53.924800</td>
#       <td>66.826400</td>
#       <td>66.839700</td>
#       <td>16.262600</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.105600</td>
#       <td>1.038640</td>
#       <td>67.771300</td>
#       <td>54.549400</td>
#       <td>67.534200</td>
#       <td>67.488700</td>
#       <td>15.994900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.038300</td>
#       <td>1.020302</td>
#       <td>68.550700</td>
#       <td>55.503900</td>
#       <td>68.421300</td>
#       <td>68.402700</td>
#       <td>15.868700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.009200</td>
#       <td>1.017749</td>
#       <td>68.340200</td>
#       <td>55.432200</td>
#       <td>68.186700</td>
#       <td>68.147300</td>
#       <td>15.833300</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.002400</td>
#       <td>1.016863</td>
#       <td>68.070700</td>
#       <td>55.278900</td>
#       <td>67.873900</td>
#       <td>67.951600</td>
#       <td>15.848500</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.989500</td>
#       <td>1.017735</td>
#       <td>68.233600</td>
#       <td>55.362800</td>
#       <td>68.034400</td>
#       <td>68.118500</td>
#       <td>15.823200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.984800</td>
#       <td>1.013406</td>
#       <td>68.084900</td>
#       <td>55.497200</td>
#       <td>67.926500</td>
#       <td>67.993100</td>
#       <td>15.818200</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1386, training_loss=1.057384100139227, metrics={'train_runtime': 930.1726, 'train_samples_per_second': 11.92, 'train_steps_per_second': 1.49, 'total_flos': 949073690492928.0, 'train_loss': 1.057384100139227, 'epoch': 7.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='25' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 00:22]
#     </div>
# {'eval_loss': 1.0203020572662354,
#  'eval_rouge1': 68.5507,
#  'eval_rouge2': 55.5039,
#  'eval_rougeL': 68.4213,
#  'eval_rougeLsum': 68.4027,
#  'eval_gen_len': 15.8687,
#  'eval_runtime': 38.25,
#  'eval_samples_per_second': 5.176,
#  'eval_steps_per_second': 0.654,
#  'epoch': 7.0}

# %%
trainer.evaluate(encoded_test_ds)
# Out:
#     <div>
#
#       <progress value='50' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 01:27]
#     </div>
# {'eval_loss': 0.9976702332496643,
#  'eval_rouge1': 66.7551,
#  'eval_rouge2': 54.7416,
#  'eval_rougeL': 66.3511,
#  'eval_rougeLsum': 66.4788,
#  'eval_gen_len': 15.2613,
#  'eval_runtime': 25.156,
#  'eval_samples_per_second': 7.911,
#  'eval_steps_per_second': 0.994,
#  'epoch': 7.0}

# %%
# save training weights
trainer.save_model('models/t5-detoxify-base2.pth')
# torch.save(model.state_dict(), 'models/t5-detoxify-base1.pth')

# %%
t5model.eval()

test_dataloader = DataLoader(encoded_test_ds, batch_size=8, collate_fn=data_collator)

generated_texts = []
with torch.no_grad():
    for batch in test_dataloader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        output = t5model.generate(input_ids=input_ids, attention_mask=attention_mask, max_length=64)
        generated_texts.extend(t5tokenizer.batch_decode(output, skip_special_tokens=True))

# %%
generated_texts[:10]
# Out:
# ['So maybe you should be more retarded.',
#  "THERE IS A MEGATHREAD FOR VACCINE OR COVID RELATED TOPICS. DON'T TALK ABOUT THAT HERE",
#  'you are on drugs',
#  'NTA. Dump his ass. Tablemanners are no rocket science. Treating other people like human beings is no rocket science. His still a child.',
#  "You're not very smart",
#  'Because everyone knows why. It’s Jadas fault. Will was just triggered because of all the things he has to deal with because of her.',
#  'And “poor kids are just as bright as white kids”.... Your blundering bafoon chooses racism as well',
#  "Tucker is a racist person that no one will miss when he's gone... he's also racist",
#  "There's plenty of evidence, it's exactly why they won't allow forensic audits *wipes voting machines clean of their records*",
#  'Came here to say this, Carlsen is a freaking moron and defines recreational outrage imo']

# %%
# Create a new DataFrame with the generated texts
df_gen = pd.DataFrame({'t5_tuning_output': generated_texts})

# Add the generated_text column to the df_test dataframe
df_t5_output = pd.concat([df_test, df_gen], axis=1)

df_t5_output.head(10)
# Out:
#                                       offensive-text  \
# 0              So maybe you should be more retarded.
# 1  THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                      the fuck.... you are on drugs
# 3  NTA.   Dump his ass. Tablemanners are no rocke...
# 4                            Youre soft as baby shit
# 5  Because everyone knows why. It’s jadas fault. ...
# 6  And “poor kids are just as bright as white kid...
# 7  Tucker is a garbage person that no one will mi...
# 8  There’s plenty of evidence, it’s exactly why t...
# 9  Came here to say this, carlsen is a freaking m...
#
#                               style-transferred-text  \
# 0               So maybe you should be more backward
# 1  THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                uh..... you are not being realistic
# 3  You should leave him. Tablemanners are no rock...
# 4                                  Youre really soft
# 5  Because everyone knows it's jadas fault. Will ...
# 6  He said "poor kids are just as bright as white...
# 7       Tucker is a bad person who instigates racism
# 8  There is evidence, which is why they won't all...
# 9  Came here to say this, carlsen is pretty unint...
#
#                                     t5_tuning_output
# 0              So maybe you should be more retarded.
# 1  THERE IS A MEGATHREAD FOR VACCINE OR COVID REL...
# 2                                   you are on drugs
# 3  NTA. Dump his ass. Tablemanners are no rocket ...
# 4                              You're not very smart
# 5  Because everyone knows why. It’s Jadas fault. ...
# 6  And “poor kids are just as bright as white kid...
# 7  Tucker is a racist person that no one will mis...
# 8  There's plenty of evidence, it's exactly why t...
# 9  Came here to say this, Carlsen is a freaking m...

# %%
# Save the updated dataframe as a CSV file
df_t5_output.to_csv('outputs/t5_tuning_output.csv',sep='\t',index=False)

# %%
## Calculate NonToxicScore
output_file = 'outputs/t5_tuning_output.csv'
output_col = 't5_tuning_output'

# Create Data Loader
score_loader = NonToxicScoreDataLoader(output_file, output_col)

# Calculate NonToxicScore
t5_NonToxicScores, avg_score = NonToxicScore(score_loader, score_model)
# Out:
# {'NonToxicScore': 0.392571528442204}

# %%
# Look at output texts with low NonToxicScore, or still classified as Toxic after Style Transfering
df_finetune = pd.read_csv('outputs/t5_tuning_output.csv',sep='\t')
df_finetune['NonToxicScore'] = t5_NonToxicScores

df_finetune_lowscore = df_finetune[df_finetune['NonToxicScore'] < 0.5][['offensive-text', 'style-transferred-text', 't5_tuning_output', 'NonToxicScore']]
df_finetune_lowscore
# Out:
#                                         offensive-text  \
# 0                So maybe you should be more retarded.
# 3    NTA.   Dump his ass. Tablemanners are no rocke...
# 6    And “poor kids are just as bright as white kid...
# 7    Tucker is a garbage person that no one will mi...
# 9    Came here to say this, carlsen is a freaking m...
# ..                                                 ...
# 191  I wish I could spit my unvaccinated saliva on ...
# 194  NTA, Jes-us your brother is dumb. How long did...
# 195  Formula one…nascar….shit it exactly the same e...
# 196  BRB, gonna go call the mods pathetic egotistic...
# 198                I think you need to check your head
#
#                                 style-transferred-text  \
# 0                 So maybe you should be more backward
# 3    You should leave him. Tablemanners are no rock...
# 6    He said "poor kids are just as bright as white...
# 7         Tucker is a bad person who instigates racism
# 9    Came here to say this, carlsen is pretty unint...
# ..                                                 ...
# 191   I wish I could weaponize my unvaccinated saliva.
# 194  NTA, your brother is not thinking straight. Ho...
# 195  Formula one…nascar….it exactly the same except...
# 196                       BRB, gonna go call the mods.
# 198                 I think you need to check yourself
#
#                                       t5_tuning_output  NonToxicScore
# 0                So maybe you should be more retarded.       0.015333
# 3    NTA. Dump his ass. Tablemanners are no rocket ...       0.001312
# 6    And “poor kids are just as bright as white kid...       0.041673
# 7    Tucker is a racist person that no one will mis...       0.154644
# 9    Came here to say this, Carlsen is a freaking m...       0.001538
# ..                                                 ...            ...
# 191  I wish I could spit my unvaccinated saliva on ...       0.033816
# 194  NTA, Jes-us your brother is dumb. How long did...       0.007379
# 195  Formula one...nascar....shit it exactly the sa...       0.001896
# 196  BRB, gonna go call the mods pathetic neck beards.       0.009486
# 198                I think you need to check your head       0.375294
#
# [122 rows x 4 columns]

# %%
for i in range(len(df_finetune_lowscore)):
    print(df_finetune_lowscore.t5_tuning_output.values[i])
    print('NonToxicScore:', df_finetune_lowscore.NonToxicScore.values[i])
# Out:
# So maybe you should be more retarded.
# NonToxicScore: 0.015332838520407677
# NTA. Dump his ass. Tablemanners are no rocket science. Treating other people like human beings is no rocket science. His still a child.
# NonToxicScore: 0.0013116915943101048
# And “poor kids are just as bright as white kids”.... Your blundering bafoon chooses racism as well
# NonToxicScore: 0.04167310148477554
# Tucker is a racist person that no one will miss when he's gone... he's also racist
# NonToxicScore: 0.1546442061662674
# Came here to say this, Carlsen is a freaking moron and defines recreational outrage imo
# NonToxicScore: 0.0015384561847895384
# This is so cringe. What a loser.
# NonToxicScore: 0.00854953471571207
# Less than no value-that's cute coming from some pretentious douchebag that can't comprehend reading comprehension lol.
# NonToxicScore: 0.005774618126451969
# we're all damned so it might as well have some fun along the way to social hell *grabs chainsaw*
# NonToxicScore: 0.009515197947621346
# Good. Stop indoctrinating kids. Let them worry about tee ball and shit, not your ceaseless victimhood
# NonToxicScore: 0.005643615499138832
# >Stop being a weasel. Address what I actually wrote or fuck off.
# NonToxicScore: 0.0012222245568409562
# I bet you make stupid assumptions, then feel smug.
# NonToxicScore: 0.005037222523242235
# Ya daughter is getting tricked out by Greek Nerds at UNC  NOW i’m a troll. Just so you know what it looks like
# NonToxicScore: 0.02714413031935692
# Really bad stance. What an unbelievable person you are.
# NonToxicScore: 0.3835955560207367
# The need to feel superior to others is by far the ugliest human trait. You are very very ugly. Eat dicks sizzle tits.
# NonToxicScore: 0.001417155610397458
# Just like Republicans creating themselves narratives to fuel their persecution complex to justify their hatred for everyone that isn't on the Jesus cock.
# NonToxicScore: 0.00520164193585515
# Liberal Antifa and Fraudchi style smear. I hope you are woke enough to see what you have coming before it hits you.
# NonToxicScore: 0.2499890923500061
# answer: technology  people (skill and just in general) people are stupid do we really need them on faster vehicles?
# NonToxicScore: 0.01978004164993763
# Bob for president! Stop apologizing to the sodomites!
# NonToxicScore: 0.027982374653220177
# Dem sponsored invasion. Stay strapped my friends.
# NonToxicScore: 0.12926289439201355
# As mentioned, he threw a plastic bag at him. Apparently in America that gives you the right to murder that person.
# NonToxicScore: 0.36001551151275635
# OP is a special kind of stupid
# NonToxicScore: 0.007022404577583075
# Damn you're actually stupid
# NonToxicScore: 0.001711615244857967
# Like the Dem addicts too when they spend their pay on smack and coke for a good rush.
# NonToxicScore: 0.20395565032958984
# You're sick. Mentally.
# NonToxicScore: 0.02066715806722641
# They literally steal and sell babies in convenience stores. Sorry but most are scum. (a small % escape their filthy culture and integrate)
# NonToxicScore: 0.005340919829905033
# what's to investigate, his duplicitous incompetence is manifest
# NonToxicScore: 0.4657643735408783
# Na. You're just a shit.
# NonToxicScore: 0.002046439563855529
# In other news 40% of Americans are racist and homophobic... and 99% of that trash supports the Republican Party. Draw your own conclusions
# NonToxicScore: 0.055293116718530655
# You're ridiculous and stupid. That's all you get from me.
# NonToxicScore: 0.0035018075723201036
# holy shit based
# NonToxicScore: 0.0015094502596184611
# My uncle is angry at me. I wish I could back and not be so stupid.
# NonToxicScore: 0.017758868634700775
# Well ketchup and mustard don't give a shitty about your feelings and your questions of physics
# NonToxicScore: 0.013322207145392895
# Yeah that dude is a shit
# NonToxicScore: 0.0025696677621454
# God I hope so. This place is a joke and every single one of you are a jerk.
# NonToxicScore: 0.0019804583862423897
# wtf that old senile delusional said he was sending us more money
# NonToxicScore: 0.004647661466151476
# Whatever. You're still full of shit and victimhood
# NonToxicScore: 0.0023291471879929304
# I think it’s a pretty safe bet that this douche hasn’t used a public water fountain since segregation ended!
# NonToxicScore: 0.006718236953020096
# I never said that that made them inferior, nor did I make fun of them. Get your white ass out of here.
# NonToxicScore: 0.0014218322467058897
# Crawl back to your echo chamber.
# NonToxicScore: 0.13599927723407745
# Why don't you stick to your weird rape fantasies and leave economics to the adults?
# NonToxicScore: 0.037884682416915894
# People publicly shame smokers for their bad choices. Why are fat people exempt from criticism?
# NonToxicScore: 0.1979004442691803
# You are both wrong and dumb, just fyi
# NonToxicScore: 0.0096781887114048
# Yeah bro I'm dumb cuz I can think on my own and I don't believe every conspiracy theory I see
# NonToxicScore: 0.012178726494312286
# I hate this guy. And everyone else that voted against this.
# NonToxicScore: 0.13428887724876404
# I hope the bastard suffered
# NonToxicScore: 0.0017616465920582414
# You too gay mod
# NonToxicScore: 0.0025284402072429657
# Kill all pedos. Why are we entertaining this madness
# NonToxicScore: 0.001643831841647625
# oh fuck off no they don't
# NonToxicScore: 0.0012723773252218962
# Turns out people that are fucked up have something wrong with them.
# NonToxicScore: 0.018799137324094772
# Why do you even contribute when you have nothing of value to share? Seriously choke on your ignorance and die a painful death.
# NonToxicScore: 0.0059846797958016396
# Go f yourself Republican scum who put us here with your uneducated voting like you even care. I do want to defund the police.
# NonToxicScore: 0.0019471602281555533
# Where do you live that is "pro democratic" because it sure as hell isn't the USA haha
# NonToxicScore: 0.04657450690865517
# The party of accountability and hypocrisy. I wonder how many other investigators got thrown in jail for looking to close.
# NonToxicScore: 0.4606316387653351
# I would not say nuts...it just looks very suspicious. Either way, the dude is a douchebag.
# NonToxicScore: 0.0024958869908005
# May Mother Russia spare you from your certain demise
# NonToxicScore: 0.05181330442428589
# Steal from Walmart.
# NonToxicScore: 0.2751806974411011
# I don't hate transgenders. I hate jousting.
# NonToxicScore: 0.11789724975824356
# I’m gonna be a poor doctor someday said no one ever.
# NonToxicScore: 0.20795904099941254
# You're seriously unhinged, nobody is upset. You honestly rant like a school shooter... we're worried.
# NonToxicScore: 0.11385555565357208
# Yeah, Reagan was truly evil.
# NonToxicScore: 0.49176985025405884
# Umm the first amendment whoopie you ugly cow.
# NonToxicScore: 0.0022113705053925514
# I'm glad people still dare ask these questions. The Internet is full of dicks, it's easy to grow timid here.
# NonToxicScore: 0.029708506539463997
# Kid fools are really mad over this.
# NonToxicScore: 0.007927422411739826
# > in JoeRogan > in Firearms For anyone who wonders where the stupid comes from.
# NonToxicScore: 0.009967045858502388
# Your tastebuds are RUDE. Return them or exchange them.
# NonToxicScore: 0.1842537224292755
# I stopped listening to her when she first spoke but those tits keep me entertained.
# NonToxicScore: 0.005007589235901833
# It’s important to remember that every single Republican is literally an individual Hitler lite
# NonToxicScore: 0.3543824553489685
# Just because you're a dumbass does not mean others are. So you only speak for yourself.
# NonToxicScore: 0.004896247759461403
# Oh so he's a Nazi Klansman Freemason? Wow that's crazy
# NonToxicScore: 0.029346229508519173
# You're both retarded
# NonToxicScore: 0.0069460179656744
# If it's past 4 months you're a monster
# NonToxicScore: 0.019489338621497154
# Only two types of people have ever supported conservatism, the evil, and the dangerously stupid.
# NonToxicScore: 0.034361377358436584
# He had a big cock at least
# NonToxicScore: 0.0015128784580156207
# Boyfriend is a jerk. I love that you dumped him. NTA for sure.
# NonToxicScore: 0.001706803566776216
# Wow, what a humble brag. Nobody cares, you're still a jerk.
# NonToxicScore: 0.0016817902214825153
# This sub is amazing! Whenever I feel dumb I slide by here and see what actual stupidity looks like. Thanks for the morale boost!
# NonToxicScore: 0.015532066114246845
# Because white people saying “I got scared” is used as justification to murder people constantly
# NonToxicScore: 0.4678526222705841
# Yes it was you are a total lie.
# NonToxicScore: 0.022984743118286133
# Meanwhile, conservatives actually bomb abortion clinics. The hypocrisy is endless.
# NonToxicScore: 0.23198014497756958
# You AINT SEEN SHIT!
# NonToxicScore: 0.0018601738847792149
# Effing ghouls pushing this bill. (D)emonic.
# NonToxicScore: 0.013476362451910973
# Nazi blood runs deep
# NonToxicScore: 0.004410440102219582
# are you retarded? there are literally laws against antisemitism in most western countries. what government is telling their citizens to hate Jews?
# NonToxicScore: 0.006229696795344353
# Reddit has got to have the greatest concentration of brain dead people on the whole internet.
# NonToxicScore: 0.2249799370765686
# Yes and said cultures thought it was alright to fuck little kids back in those days as well especially Mesopotamia. Glad we are reversing as a species.
# NonToxicScore: 0.004674367140978575
# > Lol, ok Kid. Notice you didn't refute it. Like I said. Pack of idiots. Good luck with the midterms.
# NonToxicScore: 0.005854923743754625
# On one hand Reagan said some based shit but on the other hand he took away our machine guns and started the war on drugs
# NonToxicScore: 0.003333757631480694
# Holy shit the gaslighting. Do her a favor and move yourself out of her house and just go live in the hotel.
# NonToxicScore: 0.0042187818326056
# True. We can't pretend neo Nazis are equal to normal human beings. They should be publicly hanged before they infect society
# NonToxicScore: 0.018705690279603004
# So let’s forget that buddy is traitor? Nah.
# NonToxicScore: 0.0090337498113513
# Too bad she isnt a crack smoking money embezzler like hunter, then it would be easy to make her look bad.
# NonToxicScore: 0.09270583838224411
# Who gives a fuck? Autistic people that can't even look at a camera should not be doing live TV interviews. Pretty simple.
# NonToxicScore: 0.0012684158282354474
# Haha, it won't be, they'll all be waiters in hell.
# NonToxicScore: 0.012005172669887543
# You sound like a snob
# NonToxicScore: 0.12233133614063263
# You actually fell for that? You're a retard.
# NonToxicScore: 0.00397154176607728
# What is this stupid thing?
# NonToxicScore: 0.005787759553641081
# I know if it makes me angry I should upvote and not downvote but fuck this is hard. I'm just not voting at all.
# NonToxicScore: 0.0023574212100356817
# Thank you, for acknowledging your own stupidity!
# NonToxicScore: 0.007778721395879984
# Not a kid defending himself. A little punk who deserves to be unalived.
# NonToxicScore: 0.2055940479040146
# Shut up, atheism is gay
# NonToxicScore: 0.0033463342115283012
# You are obviously homophobic
# NonToxicScore: 0.046470146626234055
# You're on the wrong subreddit to be spewing that kind of stuff. Shut up now.
# NonToxicScore: 0.010477432981133461
# It's not slapdash, it's just not appealing to my palate
# NonToxicScore: 0.3266044855117798
# What a stupid take
# NonToxicScore: 0.0016330478247255087
# You can't clean yourself if your brain is all messed up?
# NonToxicScore: 0.07729266583919525
# Stfu. Go make a new sub.
# NonToxicScore: 0.0031247935257852077
# You're a jerk. Lol
# NonToxicScore: 0.0014099220279604197
# Re-education camps for them. Cut their evil out 100%
# NonToxicScore: 0.3914962708950043
# Do have any idea how dumb that sounds???
# NonToxicScore: 0.026622723788022995
# Grow up
# NonToxicScore: 0.09551141411066055
# You call them journalists? You are laughably ignorant.
# NonToxicScore: 0.11662939935922623
# You guys love oppression. Let me get some barbecue recipes. I know you Klansmen are always having cookouts.
# NonToxicScore: 0.1213807463645935
# You mean that chick with a dick?
# NonToxicScore: 0.0018627465469762683
# Hope the stupid person who did this to you gets shot
# NonToxicScore: 0.0027359998784959316
# Anti gay equals anti human.
# NonToxicScore: 0.006350555457174778
# How else could the average person be so full of shit?
# NonToxicScore: 0.0029559782706201077
# You've been completely subverted yet here you are talking about brainwashing.
# NonToxicScore: 0.21513605117797852
# I wish I could spit my unvaccinated saliva on you and your family.
# NonToxicScore: 0.033816151320934296
# NTA, Jes-us your brother is dumb. How long did he think he could keep these kids hidden for?
# NonToxicScore: 0.007378621492534876
# Formula one...nascar....shit it exactly the same except the former has lighter cars. Who can turn left faster? The answer is! Who gives a shit.
# NonToxicScore: 0.0018960118759423494
# BRB, gonna go call the mods pathetic neck beards.
# NonToxicScore: 0.009485874325037003
# I think you need to check your head
# NonToxicScore: 0.37529391050338745
