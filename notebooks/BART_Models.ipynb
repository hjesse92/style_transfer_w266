# %% [markdown]
# # Fine Tuning BART

# %% [markdown]
# <a href="https://colab.research.google.com/github/hjesse92/style_transfer_w266/blob/main/notebooks/BART_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
# !pip install -q transformers datasets rouge_score accelerate evaluate

# %%
#Am I running a GPU and what type is it?
# !nvidia-smi
# Out:
# Sun Apr  9 02:55:49 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   25C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch

# Clear out cuda
torch.cuda.empty_cache()

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('Number of GPU(s) available:', torch.cuda.device_count())
    print('GPU device name:', torch.cuda.get_device_name(0))

else:
    print('No GPU available')
    device = torch.device("cpu")
# Out:
# Number of GPU(s) available: 1
# GPU device name: Tesla T4

# %%
from logging import warning
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler, TensorDataset

from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, AdamW, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers import AutoTokenizer, BartForConditionalGeneration
from datasets import load_metric, load_dataset


from sklearn.utils import resample
from sklearn.model_selection import train_test_split

import re
import random
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pprint
import nltk

import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/ubuntu/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ..
# cd drive/MyDrive/w266/style_transfer_w266/
# Out:
# /home/ubuntu/style_transfer_w266

# %%
train_file = 'data/original-train.tsv'
dev_file = 'data/original-dev.tsv'
test_file = 'data/original-test.tsv'
df_train = pd.read_csv(train_file, sep='\t')
df_dev = pd.read_csv(dev_file, sep='\t')
df_test = pd.read_csv(test_file, sep='\t')

# %%
print(f'''mean length of offensive text: {df_train['offensive-text'].map(len).mean()}''')
print(f'''min length of offensive text: {df_train['offensive-text'].map(len).min()}''')
print(f'''max length of offensive text: {df_train['offensive-text'].map(len).max()}''')
print(f'''mean length of neutralized text: {df_train['style-transferred-text'].map(len).mean()}''')
print(f'''min length of neutralized text: {df_train['style-transferred-text'].map(len).min()}''')
print(f'''max length of neutralized text: {df_train['style-transferred-text'].map(len).max()}''')
# Out:
# mean length of offensive text: 69.85353535353535
# min length of offensive text: 9
# max length of offensive text: 238
# mean length of neutralized text: 60.48800505050505
# min length of neutralized text: 1
# max length of neutralized text: 174

# %% [markdown]
# ## Train BART base with Trainer

# %%
dataset = load_dataset('csv', sep="\t", data_files={'train': train_file, 'validation': dev_file,'test': test_file})
# Out:
# Downloading and preparing dataset csv/default to /home/ubuntu/.cache/huggingface/datasets/csv/default-47b8eebd77563070/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /home/ubuntu/.cache/huggingface/datasets/csv/default-47b8eebd77563070/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
tokenizer = AutoTokenizer.from_pretrained("facebook/bart-base")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.72k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
prefix = 'transfer to nontoxic text: '
max_input_length = 64
max_target_length = 64


def preprocess_data(examples):
  source_inputs = [prefix + text for text in examples['offensive-text']]
  model_inputs = tokenizer(source_inputs, max_length=max_input_length, padding="max_length", truncation=True)
  
  target_inputs = [text for text in examples['style-transferred-text']]
  target_tokens = tokenizer(target_inputs, max_length=max_target_length, padding="max_length", truncation=True)
  
  # important: we need to replace the index of the padding tokens by -100
  # such that they are not taken into account by the CrossEntropyLoss
  labels_with_ignore_index = []
  for labels_example in target_tokens.input_ids:
    labels_example = [label if label != 0 else -100 for label in labels_example]
    labels_with_ignore_index.append(labels_example)
  
  model_inputs["labels"] = labels_with_ignore_index
  # model_inputs["labels"] = target_tokens
  
  return model_inputs

# %%
tokenized_datasets = dataset.map(preprocess_data, batched=True)
encoded_train_ds = dataset['train'].map(preprocess_data, batched=True, remove_columns=dataset['train'].column_names)
encoded_val_ds = dataset['validation'].map(preprocess_data, batched=True, remove_columns=dataset['validation'].column_names)
encoded_test_ds = dataset['test'].map(preprocess_data, batched=True, remove_columns=dataset['test'].column_names)
# Out:
# Map:   0%|          | 0/1584 [00:00<?, ? examples/s]
# Map:   0%|          | 0/198 [00:00<?, ? examples/s]
# Map:   0%|          | 0/199 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1584 [00:00<?, ? examples/s]
# Map:   0%|          | 0/198 [00:00<?, ? examples/s]
# Map:   0%|          | 0/199 [00:00<?, ? examples/s]

# %%
# preprocess_data(dataset['train'][0])
# tokenized_datasets['train']['input_ids'][0][0]
tokenizer.decode(tokenized_datasets['train'][0]['input_ids'])
# Out:
# '<s>transfer to nontoxic text: Pussy nobody asked for your input.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %%
tokenizer.decode(encoded_train_ds[0]['input_ids'])
# Out:
# '<s>transfer to nontoxic text: Pussy nobody asked for your input.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['offensive-text', 'style-transferred-text', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1584
#     })
#     validation: Dataset({
#         features: ['offensive-text', 'style-transferred-text', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 198
#     })
#     test: Dataset({
#         features: ['offensive-text', 'style-transferred-text', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 199
#     })
# })

# %%
encoded_train_ds
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 1584
# })

# %%
batch_size = 8
model_name = "facebook/bart-base-detoxify"
model_dir = f"models/{model_name}"

args = Seq2SeqTrainingArguments(
    model_dir,
    evaluation_strategy="epoch",
    logging_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    num_train_epochs=7,
    predict_with_generate=True,
    load_best_model_at_end=True,
    metric_for_best_model="rouge1",
    remove_unused_columns=False
)

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer)
metric = load_metric("rouge")

# %%
import nltk

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip()))
                      for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) 
                      for label in decoded_labels]
    
    # Compute ROUGE scores
    result = metric.compute(predictions=decoded_preds, references=decoded_labels,
                            use_stemmer=True)

    # Extract ROUGE f1 scores
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length to metrics
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id)
                      for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
from transformers import AdamW, get_cosine_schedule_with_warmup

model_ckpt = "facebook/bart-base"
model = BartForConditionalGeneration.from_pretrained(model_ckpt)
model = model.to(device)

optimizer = AdamW(model.parameters(), lr=2e-5)
scheduler = get_cosine_schedule_with_warmup(optimizer, num_warmup_steps=10, num_training_steps=1000)
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=args,
    # train_dataset=tokenized_datasets['train'],
    train_dataset=encoded_train_ds, 
    # eval_dataset=tokenized_datasets['validation'],
    eval_dataset=encoded_val_ds,
    data_collator=data_collator,
    tokenizer=tokenizer,
    optimizers=(optimizer, scheduler),
    compute_metrics=compute_metrics
)

# %%
# %load_ext tensorboard
# %tensorboard --logdir '{model_dir}'/runs

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='1386' max='1386' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1386/1386 06:58, Epoch 7/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.897100</td>
#       <td>0.476778</td>
#       <td>66.728200</td>
#       <td>53.412300</td>
#       <td>66.506400</td>
#       <td>66.531600</td>
#       <td>16.878800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.354200</td>
#       <td>0.272928</td>
#       <td>68.972500</td>
#       <td>56.506700</td>
#       <td>68.929300</td>
#       <td>68.855100</td>
#       <td>16.247500</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.234900</td>
#       <td>0.265647</td>
#       <td>69.151500</td>
#       <td>56.607000</td>
#       <td>69.152400</td>
#       <td>69.158300</td>
#       <td>16.368700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.201300</td>
#       <td>0.264540</td>
#       <td>69.328900</td>
#       <td>56.788400</td>
#       <td>69.287700</td>
#       <td>69.325400</td>
#       <td>16.383800</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.186900</td>
#       <td>0.266082</td>
#       <td>69.842500</td>
#       <td>57.423700</td>
#       <td>69.815800</td>
#       <td>69.769700</td>
#       <td>16.232300</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.185900</td>
#       <td>0.265690</td>
#       <td>69.595300</td>
#       <td>57.122100</td>
#       <td>69.587700</td>
#       <td>69.621900</td>
#       <td>16.358600</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.186000</td>
#       <td>0.266540</td>
#       <td>69.420300</td>
#       <td>56.980500</td>
#       <td>69.423300</td>
#       <td>69.381800</td>
#       <td>16.434300</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1386, training_loss=0.7494761892211386, metrics={'train_runtime': 419.2494, 'train_samples_per_second': 26.447, 'train_steps_per_second': 3.306, 'total_flos': 422547365560320.0, 'train_loss': 0.7494761892211386, 'epoch': 7.0})

# %%
# save training weights
trainer.save_model('models/bart-detoxify-base')
torch.save(model.state_dict(), 'models/bart-detoxify-base1.pth')

# %%
# Calculate rouge score for test set
trainer.evaluate(encoded_test_ds)
# Out:
#     <div>
#
#       <progress value='25' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 00:10]
#     </div>
# {'eval_loss': 0.26057571172714233,
#  'eval_rouge1': 69.671,
#  'eval_rouge2': 57.823,
#  'eval_rougeL': 69.1977,
#  'eval_rougeLsum': 69.2799,
#  'eval_gen_len': 15.7688,
#  'eval_runtime': 11.3529,
#  'eval_samples_per_second': 17.529,
#  'eval_steps_per_second': 2.202,
#  'epoch': 7.0}

# %%
model.eval()

test_dataloader = DataLoader(encoded_test_ds, batch_size=8, collate_fn=data_collator)

generated_texts = []
with torch.no_grad():
    for batch in test_dataloader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        output = model.generate(input_ids=input_ids, attention_mask=attention_mask, max_length=64)
        generated_texts.extend(tokenizer.batch_decode(output, skip_special_tokens=True))

# %%
generated_texts[:10]
# Out:
# ['So maybe you should be more mature.',
#  "THERES A MEGATHREAD FOR VACCINE OR COVID RELATED TOPICS. DON'T TALK ABOUT THAT.",
#  'you are on drugs',
#  'NTA.   Dump his tablemanners. Treating other people like human beings is no rocket science. His still a child.',
#  'Youre soft as baby',
#  "Because everyone knows why. It's jadas fault. Will was just triggered because of all the stuff he has to deal with because of her.",
#  'And “poor kids are just as bright as white kids”…. Your ignorance chooses racism as well',
#  "Tucker is a bad person that no one will miss when he's gone… he’s also a racist",
#  "There's plenty of evidence, it's exactly why they won't allow forensic audits   *wipes voting machines clean of their records*",
#  ' Came here to say this, carlsen is not very smart and defines recreational outrage imo']

# %%
# Create a new DataFrame with the generated texts
df_gen = pd.DataFrame({'bart_tuning_output': generated_texts})

# Add the generated_text column to the df_test dataframe
df_output = pd.concat([df_test, df_gen], axis=1)

df_output.head(10)
# Out:
#                                       offensive-text  \
# 0              So maybe you should be more retarded.
# 1  THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                      the fuck.... you are on drugs
# 3  NTA.   Dump his ass. Tablemanners are no rocke...
# 4                            Youre soft as baby shit
# 5  Because everyone knows why. It’s jadas fault. ...
# 6  And “poor kids are just as bright as white kid...
# 7  Tucker is a garbage person that no one will mi...
# 8  There’s plenty of evidence, it’s exactly why t...
# 9  Came here to say this, carlsen is a freaking m...
#
#                               style-transferred-text  \
# 0               So maybe you should be more backward
# 1  THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                uh..... you are not being realistic
# 3  You should leave him. Tablemanners are no rock...
# 4                                  Youre really soft
# 5  Because everyone knows it's jadas fault. Will ...
# 6  He said "poor kids are just as bright as white...
# 7       Tucker is a bad person who instigates racism
# 8  There is evidence, which is why they won't all...
# 9  Came here to say this, carlsen is pretty unint...
#
#                                   bart_tuning_output
# 0                So maybe you should be more mature.
# 1  THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                                   you are on drugs
# 3  NTA.   Dump his tablemanners. Treating other p...
# 4                                 Youre soft as baby
# 5  Because everyone knows why. It's jadas fault. ...
# 6  And “poor kids are just as bright as white kid...
# 7  Tucker is a bad person that no one will miss w...
# 8  There's plenty of evidence, it's exactly why t...
# 9   Came here to say this, carlsen is not very sm...

# %%
# Save the updated dataframe as a CSV file
df_output.to_csv('outputs/bart_tuning_output.csv',sep='\t',index=False)

# %%
import sys
sys.path.append('./notebooks')
from DistilBertClassification import BertClassificationML, NonToxicScoreDataLoader, NonToxicScore

# Load DistilBERT Classification Model to calculate NonToxicScore
score_model = BertClassificationML()
score_model = score_model.to(device)

# Load training weights
pretrained_weights = torch.load('models/DistilBertToxicClassification7.pth')
score_model.load_state_dict(pretrained_weights )
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_projector.weight', 'vocab_projector.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <All keys matched successfully>

# %%
## Calculate NonToxicScore
output_file = 'outputs/bart_tuning_output.csv'
output_col = 'bart_tuning_output'

# Create Data Loader
score_loader = NonToxicScoreDataLoader(output_file, output_col, max_length=512)

# Calculate NonToxicScore
bart_NonToxicScores, avg_score = NonToxicScore(score_loader, score_model)
# Out:
# {'NonToxicScore': 0.5762933659584883}

# %%
# Look at output texts with low NonToxicScore, or still classified as Toxic after Style Transfering
df_finetune = pd.read_csv('outputs/bart_tuning_output.csv',sep='\t')
df_finetune['NonToxicScore'] = bart_NonToxicScores

df_finetune_lowscore = df_finetune[df_finetune['NonToxicScore'] < 0.5][['offensive-text', 'style-transferred-text', 'bart_tuning_output', 'NonToxicScore']]
df_finetune_lowscore
# Out:
#                                         offensive-text  \
# 3    NTA.   Dump his ass. Tablemanners are no rocke...
# 6    And “poor kids are just as bright as white kid...
# 7    Tucker is a garbage person that no one will mi...
# 9    Came here to say this, carlsen is a freaking m...
# 10         Fuck off dude. Worst of  the fucking worst!
# ..                                                 ...
# 187   Anti gay equals anti human. Fuck you Putin nazis
# 190  You’ve been completely subverted yet here you ...
# 191  I wish I could spit my unvaccinated saliva on ...
# 195  Formula one…nascar….shit it exactly the same e...
# 198                I think you need to check your head
#
#                                 style-transferred-text  \
# 3    You should leave him. Tablemanners are no rock...
# 6    He said "poor kids are just as bright as white...
# 7         Tucker is a bad person who instigates racism
# 9    Came here to say this, carlsen is pretty unint...
# 10                      Stop dude. Worst of the worst!
# ..                                                 ...
# 187                         Anti gay equals anti human
# 190  It's a little ironic that you've been subverte...
# 191   I wish I could weaponize my unvaccinated saliva.
# 195  Formula one…nascar….it exactly the same except...
# 198                 I think you need to check yourself
#
#                                     bart_tuning_output  NonToxicScore
# 3    NTA.   Dump his tablemanners. Treating other p...       0.025178
# 6    And “poor kids are just as bright as white kid...       0.020789
# 7    Tucker is a bad person that no one will miss w...       0.111267
# 9     Came here to say this, carlsen is not very sm...       0.485712
# 10                    Leave dude. Worst of  the worst!       0.251839
# ..                                                 ...            ...
# 187                        Anti gay equals anti human.       0.006351
# 190  You've been completely subverted yet here you ...       0.200510
# 191        I wish I could spit on you and your family.       0.013394
# 195  Formula one…nascar….shit it exactly the same e...       0.005856
# 198                I think you need to check your head       0.375294
#
# [85 rows x 4 columns]

# %%
for i in range(len(df_finetune_lowscore)):
    print('Toxic Text:', df_finetune_lowscore['offensive-text'].values[i])
    print('Style Transfer Text:', df_finetune_lowscore.bart_tuning_output.values[i])
    print('NonToxicScore:', df_finetune_lowscore.NonToxicScore.values[i])
# Out:
# Toxic Text: NTA.   Dump his ass. Tablemanners are no rocket science. Treating other people like human beings is no rocket science. His still a child.
# Style Transfer Text: NTA.   Dump his tablemanners. Treating other people like human beings is no rocket science. His still a child.
# NonToxicScore: 0.025178326293826103
# Toxic Text: And “poor kids are just as bright as white kids”…. Your blundering bafoon chooses racism as well
# Style Transfer Text: And “poor kids are just as bright as white kids”…. Your ignorance chooses racism as well
# NonToxicScore: 0.020789258182048798
# Toxic Text: Tucker is a garbage person that no one will miss when he’s gone… he’s also a racist ruble-rouser
# Style Transfer Text: Tucker is a bad person that no one will miss when he's gone… he’s also a racist
# NonToxicScore: 0.11126653105020523
# Toxic Text: Came here to say this, carlsen is a freaking moron and defines recreational outrage imo
# Style Transfer Text:  Came here to say this, carlsen is not very smart and defines recreational outrage imo
# NonToxicScore: 0.4857121407985687
# Toxic Text: Fuck off dude. Worst of  the fucking worst!
# Style Transfer Text: Leave dude. Worst of  the worst!
# NonToxicScore: 0.25183913111686707
# Toxic Text: This is so cringe. What a fucking loser.
# Style Transfer Text: This is so cringe. What a loser.
# NonToxicScore: 0.00854953471571207
# Toxic Text: we're all damned so fuck it might as well have some fun along the way to social hell   \*grabs chainsaw\*
# Style Transfer Text: It's not slapdash, it's just not appealing to my palate
# NonToxicScore: 0.3266044855117798
# Toxic Text: You cant clean yourself if your brain is all fucked up?
# Style Transfer Text: You cant clean yourself if your brain is all messed up?
# NonToxicScore: 0.062241747975349426
# Toxic Text: Stfu.  Go make a new sub.
# Style Transfer Text: Stfu.  Go make a new sub.
# NonToxicScore: 0.0031247935257852077
# Toxic Text: Re-education camps for them. Cut their evil out 100%
# Style Transfer Text: Re-education camps for them. Cut their evil out 100%
# NonToxicScore: 0.3914962708950043
# Toxic Text: You call them journalists?  You are laughably ignorant.
# Style Transfer Text: You call them journalists? You are laughably ignorant.
# NonToxicScore: 0.11662939935922623
# Toxic Text: You guys love oppression. Let me get some barbecue recipes. I know you Klansmen are always having cookouts.
# Style Transfer Text: You guys love oppression. Let me get some barbecue recipes. I know you Klansmen are always having cookouts.
# NonToxicScore: 0.1213807463645935
# Toxic Text: You mean that chick with a dick?
# Style Transfer Text: You mean that chick?
# NonToxicScore: 0.25180602073669434
# Toxic Text: Anti gay equals anti human. Fuck you Putin nazis
# Style Transfer Text: Anti gay equals anti human.
# NonToxicScore: 0.006350555457174778
# Toxic Text: You’ve been completely subverted yet here you are talking about brainwashing. 🤡
# Style Transfer Text: You've been completely subverted yet here you are talking about brainwashing. 🤡
# NonToxicScore: 0.20051048696041107
# Toxic Text: I wish I could spit my unvaccinated saliva on you and your family.
# Style Transfer Text: I wish I could spit on you and your family.
# NonToxicScore: 0.013394147157669067
# Toxic Text: Formula one…nascar….shit it exactly the same except the former has lighter cars.   Who can turn left faster? The answer is!   Who gives a shit.
# Style Transfer Text: Formula one…nascar….shit it exactly the same except the former has lighter cars. Who can turn left faster? The answer is!   Who cares.
# NonToxicScore: 0.00585621502250433
# Toxic Text: I think you need to check your head
# Style Transfer Text: I think you need to check your head
# NonToxicScore: 0.37529391050338745

# %% [markdown]
# ## Train BART large with Trainer

# %%
tokenizer = AutoTokenizer.from_pretrained("facebook/bart-large")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
prefix = 'transfer to nontoxic text: '
max_input_length = 256
max_target_length = 256


def preprocess_data(examples):
  source_inputs = [prefix + text for text in examples['offensive-text']]
  model_inputs = tokenizer(source_inputs, max_length=max_input_length, padding="max_length", truncation=True)
  
  target_inputs = [text for text in examples['style-transferred-text']]
  target_tokens = tokenizer(target_inputs, max_length=max_target_length, padding="max_length", truncation=True)
  
  # important: we need to replace the index of the padding tokens by -100
  # such that they are not taken into account by the CrossEntropyLoss
  labels_with_ignore_index = []
  for labels_example in target_tokens.input_ids:
    labels_example = [label if label != 0 else -100 for label in labels_example]
    labels_with_ignore_index.append(labels_example)
  
  model_inputs["labels"] = labels_with_ignore_index
  # model_inputs["labels"] = target_tokens
  
  return model_inputs

# %%
encoded_train_ds = dataset['train'].map(preprocess_data, batched=True, remove_columns=dataset['train'].column_names)
encoded_val_ds = dataset['validation'].map(preprocess_data, batched=True, remove_columns=dataset['validation'].column_names)
encoded_test_ds = dataset['test'].map(preprocess_data, batched=True, remove_columns=dataset['test'].column_names)
# Out:
# Map:   0%|          | 0/1584 [00:00<?, ? examples/s]
# Map:   0%|          | 0/198 [00:00<?, ? examples/s]
# Map:   0%|          | 0/199 [00:00<?, ? examples/s]

# %%
tokenizer.decode(encoded_train_ds[0]['input_ids'])
# Out:
# '<s>transfer to nontoxic text: Pussy nobody asked for your input.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'

# %%
encoded_train_ds
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 1584
# })

# %%
batch_size = 8
model_name = "facebook/bart-large-detoxify"
model_dir = f"models/{model_name}"

args = Seq2SeqTrainingArguments(
    model_dir,
    evaluation_strategy="epoch",
    logging_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    num_train_epochs=4,
    predict_with_generate=True,
    load_best_model_at_end=True,
    metric_for_best_model="rouge1",
    remove_unused_columns=False
)

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer)
metric = load_metric("rouge")
# Out:
# Downloading builder script:   0%|          | 0.00/2.17k [00:00<?, ?B/s]

# %%
import nltk

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip()))
                      for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) 
                      for label in decoded_labels]
    
    # Compute ROUGE scores
    result = metric.compute(predictions=decoded_preds, references=decoded_labels,
                            use_stemmer=True)

    # Extract ROUGE f1 scores
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length to metrics
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id)
                      for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
from transformers import AdamW, get_cosine_schedule_with_warmup

model_ckpt = "facebook/bart-large"
model = BartForConditionalGeneration.from_pretrained(model_ckpt)
model = model.to(device)

optimizer = AdamW(model.parameters(), lr=2e-5)
scheduler = get_cosine_schedule_with_warmup(optimizer, num_warmup_steps=10, num_training_steps=1000)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/1.02G [00:00<?, ?B/s]

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=args,
    train_dataset=encoded_train_ds, 
    eval_dataset=encoded_val_ds,
    data_collator=data_collator,
    tokenizer=tokenizer,
    optimizers=(optimizer, scheduler),
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='792' max='792' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [792/792 24:03, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>6.211400</td>
#       <td>1.938908</td>
#       <td>60.083300</td>
#       <td>46.884600</td>
#       <td>59.508800</td>
#       <td>59.968200</td>
#       <td>17.893900</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.660200</td>
#       <td>0.079353</td>
#       <td>52.593400</td>
#       <td>44.153400</td>
#       <td>52.436400</td>
#       <td>52.769200</td>
#       <td>13.383800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.064700</td>
#       <td>0.061032</td>
#       <td>70.244200</td>
#       <td>57.791700</td>
#       <td>70.093900</td>
#       <td>70.202900</td>
#       <td>16.444400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.046800</td>
#       <td>0.060897</td>
#       <td>70.045800</td>
#       <td>57.079600</td>
#       <td>69.604000</td>
#       <td>69.859400</td>
#       <td>16.464600</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=792, training_loss=1.7457974342384723, metrics={'train_runtime': 1508.765, 'train_samples_per_second': 4.199, 'train_steps_per_second': 0.525, 'total_flos': 3432693689745408.0, 'train_loss': 1.7457974342384723, 'epoch': 4.0})

# %%
# save training weights
# trainer.save_model('models/bart-large-detoxify')
torch.save(model.state_dict(), 'models/bart-large-detoxify.pth')

# %%
# Calculate rouge score for test set
# trainer.evaluate(encoded_test_ds)

# %%
model.eval()

test_dataloader = DataLoader(encoded_test_ds, batch_size=1, collate_fn=data_collator)

generated_texts = []
with torch.no_grad():
    for batch in test_dataloader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        output = model.generate(input_ids=input_ids, 
                                attention_mask=attention_mask, 
                                max_length=256,
                                min_length=5,
                                num_beams=5,
                                early_stopping=True,
                                top_k=50,
                                length_penalty=2, #1.2
                                repetition_penalty=1,
                                no_repeat_ngram_size=5,
                                top_p = 0.95,
                                temperature=0.8,
                               )
        gen_texts = tokenizer.batch_decode(output, skip_special_tokens=True)
        if len(gen_texts) == 0:
            gen_texts = 'None'
        generated_texts.extend(gen_texts)

# %%
generated_texts[:20]
# Out:
# ['So maybe you should be more backward.',
#  "THERES A MEGATHREAD FOR VACCINE OR COVID RELATED TOPICS. DON'T TALK ABOUT THAT SHIT HERE!",
#  'the fuck.... you are on drugs',
#  'NTA. Tablemanners are no rocket science. Treating other people like human beings is no rocket science. His still a child.   Dump his ass.',
#  'Youre soft as a baby',
#  "Because everyone knows why. It's jadas fault. Will was just triggered because of all the stuff he has to deal with because of her.",
#  'And "poor kids are just as bright as white kids"…. Your blundering bafoon chooses racism as well',
#  'Tucker is a bad person that no one will miss when he’s gone… he’s also a racist',
#  'There’s plenty of evidence, it’s exactly why they won’t allow forensic audits.',
#  'Came here to say this, carlsen is not smart and defines recreational outrage imo',
#  'You should leave dude. Worst of  the worst!',
#  'This is so cringe. What a loser.',
#  'Trump deferred to the experts on COVID?? LMFAO  LMFAO  Christ this sub needs help',
#  'What is this supposed to mean?',
#  'Jesus H Christ. Get a lawyer and a therapist, immediately.',
#  "Less than no value-that's cute coming from someone who can't comprehend reading comprehension lol.",
#  "But but but but what about this other guy. But but but but this isn't fair.",
#  "We're all damned so we might as well have some fun along the way to social hell   \\*grabs chainsaw\\*",
#  "Have you ever had salt water? It's gross.",
#  'Stop indoctrinating kids. Let them worry about tee ball and stuff, not your ceeless victimhood']

# %%
# Create a new DataFrame with the generated texts
df_gen = pd.DataFrame({'bart_tuning_output': generated_texts})

# Add the generated_text column to the df_test dataframe
df_output = pd.concat([df_test, df_gen], axis=1)

df_output.head(10)
# Out:
#                                       offensive-text  \
# 0              So maybe you should be more retarded.
# 1  THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                      the fuck.... you are on drugs
# 3  NTA.   Dump his ass. Tablemanners are no rocke...
# 4                            Youre soft as baby shit
# 5  Because everyone knows why. It’s jadas fault. ...
# 6  And “poor kids are just as bright as white kid...
# 7  Tucker is a garbage person that no one will mi...
# 8  There’s plenty of evidence, it’s exactly why t...
# 9  Came here to say this, carlsen is a freaking m...
#
#                               style-transferred-text  \
# 0               So maybe you should be more backward
# 1  THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                uh..... you are not being realistic
# 3  You should leave him. Tablemanners are no rock...
# 4                                  Youre really soft
# 5  Because everyone knows it's jadas fault. Will ...
# 6  He said "poor kids are just as bright as white...
# 7       Tucker is a bad person who instigates racism
# 8  There is evidence, which is why they won't all...
# 9  Came here to say this, carlsen is pretty unint...
#
#                                   bart_tuning_output
# 0              So maybe you should be more backward.
# 1  THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                      the fuck.... you are on drugs
# 3  NTA. Tablemanners are no rocket science. Treat...
# 4                               Youre soft as a baby
# 5  Because everyone knows why. It's jadas fault. ...
# 6  And "poor kids are just as bright as white kid...
# 7  Tucker is a bad person that no one will miss w...
# 8  There’s plenty of evidence, it’s exactly why t...
# 9  Came here to say this, carlsen is not smart an...

# %%
# Save the updated dataframe as a CSV file
df_output.to_csv('outputs/bart_large_output.csv',sep='\t',index=False)

# %%
import evaluate

rouge = evaluate.load('rouge')
df_finetune = pd.read_csv('outputs/bart_large_output.csv',sep='\t')

print(rouge.compute(predictions=df_finetune['bart_tuning_output'],
              references=df_finetune['style-transferred-text']))
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.7097840080652402, 'rouge2': 0.5928976110537655, 'rougeL': 0.7050859424909693, 'rougeLsum': 0.7055850716312693}

# %%
import sys
sys.path.append('./notebooks')
from DistilBertClassification import BertClassificationML, NonToxicScoreDataLoader, NonToxicScore

# Load DistilBERT Classification Model to calculate NonToxicScore
score_model = BertClassificationML()
score_model = score_model.to(device)

# Load training weights
pretrained_weights = torch.load('models/DistilBertToxicClassification7.pth')
score_model.load_state_dict(pretrained_weights )
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_projector.bias', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <All keys matched successfully>

# %%
## Calculate NonToxicScore
output_file = 'outputs/bart_large_output.csv'
output_col = 'bart_tuning_output'

# Create Data Loader
score_loader = NonToxicScoreDataLoader(output_file, output_col, max_length=256)

# Calculate NonToxicScore
bart_NonToxicScores, avg_score = NonToxicScore(score_loader, score_model)
# Out:
# {'NonToxicScore': 0.5822367728793123}

# %%
# Look at output texts with low NonToxicScore, or still classified as Toxic after Style Transfering
df_finetune['NonToxicScore'] = bart_NonToxicScores

df_finetune_lowscore = df_finetune[df_finetune['NonToxicScore'] < 0.5][['offensive-text', 'style-transferred-text', 'bart_tuning_output', 'NonToxicScore']]
df_finetune_lowscore
# Out:
#                                         offensive-text  \
# 1    THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                        the fuck.... you are on drugs
# 3    NTA.   Dump his ass. Tablemanners are no rocke...
# 6    And “poor kids are just as bright as white kid...
# 7    Tucker is a garbage person that no one will mi...
# ..                                                 ...
# 185                   You mean that chick with a dick?
# 187   Anti gay equals anti human. Fuck you Putin nazis
# 190  You’ve been completely subverted yet here you ...
# 191  I wish I could spit my unvaccinated saliva on ...
# 198                I think you need to check your head
#
#                                 style-transferred-text  \
# 1    THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                  uh..... you are not being realistic
# 3    You should leave him. Tablemanners are no rock...
# 6    He said "poor kids are just as bright as white...
# 7         Tucker is a bad person who instigates racism
# ..                                                 ...
# 185                   You mean that transgender woman?
# 187                         Anti gay equals anti human
# 190  It's a little ironic that you've been subverte...
# 191   I wish I could weaponize my unvaccinated saliva.
# 198                 I think you need to check yourself
#
#                                     bart_tuning_output  NonToxicScore
# 1    THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...       0.002315
# 2                        the fuck.... you are on drugs       0.001292
# 3    NTA. Tablemanners are no rocket science. Treat...       0.001268
# 6    And "poor kids are just as bright as white kid...       0.035160
# 7    Tucker is a bad person that no one will miss w...       0.097477
# ..                                                 ...            ...
# 185                   You mean that chick with a dick?       0.001863
# 187        Anti gay equals anti human. You Putin nazis       0.001873
# 190  You've been completely subverted yet here you ...       0.200511
# 191  I wish I could spit my unvaccinated saliva on ...       0.016229
# 198                I think you need to check your head       0.375294
#
# [79 rows x 4 columns]

# %%
for i in range(len(df_finetune_lowscore)):
    print('\nToxic Text:', df_finetune_lowscore['offensive-text'].values[i])
    print('Style Transfer Text:', df_finetune_lowscore.bart_tuning_output.values[i])
    print('NonToxicScore:', df_finetune_lowscore.NonToxicScore.values[i])
# Out:
# Toxic Text: THERES A MEGATHREAD FOR VACCINE OR COVID RELATED TOPICS. DON'T TALK ABOUT THAT SHIT HERE IDIOT!
# Style Transfer Text: THERES A MEGATHREAD FOR VACCINE OR COVID RELATED TOPICS. DON'T TALK ABOUT THAT SHIT HERE!
# NonToxicScore: 0.002315197605639696
#
# Toxic Text: the fuck.... you are on drugs
# Style Transfer Text: the fuck.... you are on drugs
# NonToxicScore: 0.0012915487168356776
#
# Toxic Text: NTA.   Dump his ass. Tablemanners are no rocket science. Treating other people like human beings is no rocket science. His still a child.
# Style Transfer Text: NTA. Tablemanners are no rocket science. Treating other people like human beings is no rocket science. His still a child.   Dump his ass.
# NonToxicScore: 0.0012678998755291104
#
# Toxic Text: And “poor kids are just as bright as white kids”…. Your blundering bafoon chooses racism as well
# Style Transfer Text: And "poor kids are just as bright as white kids"…. Your blundering bafoon chooses racism as well
# NonToxicScore: 0.0351598784327507
#
# Toxic Text: Tucker is a garbage person that no one will miss when he’s gone… he’s also a racist ruble-rouser
# Style Transfer Text: Tucker is a bad person that no one will miss when he’s gone… he’s also a racist
# NonToxicScore: 0.09747667610645294
#
# Toxic Text: Came here to say this, carlsen is a freaking moron and defines recreational outrage imo
# Style Transfer Text: Came here to say this, carlsen is not smart and defines recreational outrage imo
# NonToxicScore: 0.19352395832538605
#
# Toxic Text: Fuck off dude. Worst of  the fucking worst!
# Style Transfer Text: You should leave dude. Worst of  the worst!
# NonToxicScore: 0.17680038511753082
#
# Toxic Text: This is so cringe. What a fucking loser.
# Style Transfer Text: This is so cringe. What a loser.
# NonToxicScore: 0.00854953471571207
#
# Toxic Text: we're all damned so fuck it might as well have some fun along the way to social hell   \*grabs chainsaw\*
# Style Transfer Text: We're all damned so we might as well have some fun along the way to social hell   \*grabs chainsaw\*
# NonToxicScore: 0.009011860936880112
#
# Toxic Text: Good. Stop fucking indoctrinating kids. Let them worry about tee ball and shit, not your ceaseless victimhood
# Toxic Text: I stopped listening to her when she first spoke but those tits keep me entertained.
# Style Transfer Text: I stopped listening to her when she first spoke but those tits keep me entertained.
# NonToxicScore: 0.005007591564208269
#
# Toxic Text: Terrifying. It’s important to remember that every single Republican is literally an individual Hitler lite
# Style Transfer Text: It's important to remember that every single Republican is literally an individual Hitler lite.
# NonToxicScore: 0.3513564169406891
#
# Toxic Text: Oh so he's a Nazi Klansman Freemason? Wow that's crazy
# Style Transfer Text: Oh so he's a Nazi Klansman Freemason? Wow that's crazy
# NonToxicScore: 0.029346195980906487
#
# Toxic Text: 90% of truckers are already vaccinated lol.    Bunch of bitch ass cry babys :’(
# Style Transfer Text: 90% of truckers are already vaccinated lol.    Bunch of cry babies :'(
# NonToxicScore: 0.1949048787355423
#
# Toxic Text: if it's past 4 months you're a monster
# Style Transfer Text: If it's past 4 months you're a monster
# NonToxicScore: 0.019489355385303497
#
# Toxic Text: He had a big cock at least
# Style Transfer Text: He had a big cock at least
# NonToxicScore: 0.0015128778759390116
#
# Toxic Text: Wow, what a humble brag. Fuck off, dude. Nobody cares, you're still a dick.
# Style Transfer Text: Wow, what a humble brag. Nobody cares, you're still being rude.
# NonToxicScore: 0.08393152803182602
#
# Toxic Text: This sub is amazing! Whenever I feel dumb I slide by here and see what actual stupidity looks like. Thanks for the morale boost!
# Style Transfer Text: This sub is amazing! Whenever I feel dumb I slide by here and see what actual stupidity looks like. Thanks for the morale boost!
# NonToxicScore: 0.015532095916569233
#
# Toxic Text: Because white people saying “I got scared “is used as justification to murder people constantly
# Style Transfer Text: Because white people saying “I got scared “is used as justification to murder people constantly
# NonToxicScore: 0.4550447463989258
#
# Toxic Text: Meanwhile, conservatives actually bomb abortion clinics. The hypocrisy is endless.
# Style Transfer Text: Meanwhile, conservatives actually bomb abortion clinics. The hypocrisy is endless.
# NonToxicScore: 0.2319801151752472
#
# Toxic Text: You  AINT SEEN SHIT!
# Style Transfer Text: You  AINT SEEN SHIT!
# NonToxicScore: 0.0018601738847792149
#
# Toxic Text: Effing ghouls pushing this bill. (D)emonic.
# Style Transfer Text: Effing ghouls pushing this bill.
# NonToxicScore: 0.006742826662957668
#
# Toxic Text: Nazi blood runs deep
# Style Transfer Text: Nazi blood runs deep
# NonToxicScore: 0.004410446155816317
#
# Toxic Text: Fuck me reddit has got to have the greatest concentration of brain dead idiots on the whole internet.
# Style Transfer Text: I think reddit has got the greatest concentration of brain dead people on the whole internet.
# NonToxicScore: 0.21458424627780914
#
# Toxic Text: True. We can't pretend neo Nazis are equal to normal human beings. They should be publicly hanged before they infect society
# Style Transfer Text: True. We can't pretend neo Nazis are equal to normal human beings. They should be publicly hanged before they infect society
# NonToxicScore: 0.018705666065216064
#
# Toxic Text: So let’s forget that buddy is traitor? Nah.
# Style Transfer Text: So let's forget that buddy is traitor? Nah.
# NonToxicScore: 0.011799769476056099
#
# Toxic Text: Too bad she isnt a crack smoking pedophile money embezzler like hunter, then it would be easy to make her look bad.
# Style Transfer Text: Too bad she isnt a crack smoking pedophile money embezzler like hunter, then it would be easy to make her look bad
# NonToxicScore: 0.018446100875735283
#
# Toxic Text: Haha, it won't be, they'll all be waiters in hell.
# Style Transfer Text: Haha, it won't be, they'll all be waiters in hell
# NonToxicScore: 0.018479151651263237
#
# Toxic Text: You sound so fucking cringe dude haha. Are you a neck beard?
# Style Transfer Text: You sound so cringe dude haha. Are you a neck beard?
# NonToxicScore: 0.039620719850063324
#
# Toxic Text: So it's not cheating if you fuck somebody and it never comes up?
# Style Transfer Text: So it's not cheating if you fuck somebody and it never comes up?
# NonToxicScore: 0.0014503509737551212
#
# Toxic Text: thank you, for acknowledging your own stupidity!
# Style Transfer Text: Thank you, for acknowledging your own ignorance!
# NonToxicScore: 0.3808186650276184
#
# Toxic Text: Not a kid defending himself. A little punk bitch who deserves to be unalived.
# Style Transfer Text: Not a kid defending himself. A little punk who deserves to suffer.
# NonToxicScore: 0.019832521677017212
#
# Toxic Text: Shut up, atheism is gay
# Style Transfer Text: Stop talking, atheism is gay
# NonToxicScore: 0.056566670536994934
#
# Toxic Text: You are obviously a homofobe
# Style Transfer Text: You are obviously prejudiced against homos.
# NonToxicScore: 0.08202610909938812
#
# Toxic Text: You're on the wrong subreddit to be spewing that kind of shit. Shut the fuck up now.
# Style Transfer Text: You're on the wrong subreddit to be spewing that kind of stuff. Shut up now.
# NonToxicScore: 0.010477407835423946
#
# Toxic Text: It’s not slapdash, it’s just not appealing to my palate
# Style Transfer Text: It's not slapdash, it's just not appealing to my palate
# NonToxicScore: 0.32660314440727234
#
# Toxic Text: What a stupid take
# Style Transfer Text: What a stupid take
# NonToxicScore: 0.001633047009818256
#
# Toxic Text: You cant clean yourself if your brain is all fucked up?
# Style Transfer Text: You cant clean yourself if your brain is messed up?
# NonToxicScore: 0.06217328831553459
#
# Toxic Text: Stfu.  Go make a new sub.
# Style Transfer Text: Stfu.  Go make a new sub.
# NonToxicScore: 0.0031247935257852077
#
# Toxic Text: Grow the fuck up
# Style Transfer Text: Grow up
# NonToxicScore: 0.09551133960485458
#
# Toxic Text: You call them journalists?  You are laughably ignorant.
# Style Transfer Text: You call them journalists?  You are laughably ignorant.
# NonToxicScore: 0.11662966012954712
#
# Toxic Text: You guys love oppression. Let me get some barbecue recipes. I know you Klansmen are always having cookouts.
# Style Transfer Text: You guys love oppression. Let me get some barbecue recipes. I know you Klansmen are always having cookouts.
# NonToxicScore: 0.12138096988201141
#
# Toxic Text: You mean that chick with a dick?
# Style Transfer Text: You mean that chick with a dick?
# NonToxicScore: 0.001862747478298843
#
# Toxic Text: Anti gay equals anti human. Fuck you Putin nazis
# Style Transfer Text: Anti gay equals anti human. You Putin nazis
# NonToxicScore: 0.0018727283459156752
#
# Toxic Text: You’ve been completely subverted yet here you are talking about brainwashing. 🤡
# Style Transfer Text: You've been completely subverted yet here you are talking about brainwashing. 🤡
# NonToxicScore: 0.200510635972023
#
# Toxic Text: I wish I could spit my unvaccinated saliva on you and your family.
# Style Transfer Text: I wish I could spit my unvaccinated saliva on you.
# NonToxicScore: 0.01622874289751053
#
# Toxic Text: I think you need to check your head
# Style Transfer Text: I think you need to check your head
# NonToxicScore: 0.3752938210964203
