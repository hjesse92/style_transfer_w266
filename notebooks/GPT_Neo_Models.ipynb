# %% [markdown]
# # GPT-Neo Models

# %% [markdown]
# <a href="https://colab.research.google.com/github/hjesse92/style_transfer_w266/blob/main/notebooks/GPT_Neo_Models.ipynb" target="_parent"><img src="https://
# colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
# !pip install -q transformers rouge_score accelerate evaluate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 53.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 KB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 15.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 105.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 KB 43.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 16.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 25.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 29.2 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %%
#Am I running a GPU and what type is it?
# !nvidia-smi
# Out:
# Sat Apr  1 22:18:07 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch

# Clear out cuda
torch.cuda.empty_cache()

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('Number of GPU(s) available:', torch.cuda.device_count())
    print('GPU device name:', torch.cuda.get_device_name(0))

else:
    print('No GPU available')
    device = torch.device("cpu")
# Out:
# Number of GPU(s) available: 1
# GPU device name: Tesla T4

# %%
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from transformers import GPTNeoForCausalLM, AutoTokenizer
# from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, AdamW, Seq2SeqTrainingArguments, Seq2SeqTrainer

import re
import random
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pprint
import nltk

from logging import warning
import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/w266/style_transfer_w266/
# Out:
# /content/drive/MyDrive/w266/style_transfer_w266

# %%
train_file = 'data/original-train.tsv'
dev_file = 'data/original-dev.tsv'
test_file = 'data/original-test.tsv'
df_train = pd.read_csv(train_file, sep='\t')
df_dev = pd.read_csv(dev_file, sep='\t')
df_test = pd.read_csv(test_file, sep='\t')

# %% [markdown]
# ## Few Shot Learning GPT-Neo 1.3B

# %%
#@title 3-Shot Learning
df_fewshot = df_test.copy()
n_shots = 3

for row in range(len(df_fewshot)):
    #For each item in the test set, we use 3 examples from the training set to as n-shots
    sources_targets = df_train.sample(n_shots, replace=False)

    for i in range(n_shots):
        df_fewshot.loc[row, f'shot{i+1}_source'] = sources_targets.iloc[i,0]
        df_fewshot.loc[row, f'shot{i+1}_target'] = sources_targets.iloc[i,1]


df_fewshot = df_fewshot.rename(columns={'offensive-text':'source', 'style-transferred-text':'target'})
df_fewshot.head()
# Out:
#                                               source  \
# 0              So maybe you should be more retarded.
# 1  THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                      the fuck.... you are on drugs
# 3  NTA.   Dump his ass. Tablemanners are no rocke...
# 4                            Youre soft as baby shit
#
#                                               target  \
# 0               So maybe you should be more backward
# 1  THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                uh..... you are not being realistic
# 3  You should leave him. Tablemanners are no rock...
# 4                                  Youre really soft
#
#                                         shot1_source  \
# 0            Has been a US military puppet from jump
# 1      wasn't that like 12 feds and an autistic fuck
# 2  This guy is overrated..... But he is right abo...
# 3                      You don’t deserve it dumbass.
# 4  Don't dare say a word, whitey. We run this lib...
#
#                                         shot1_target  \
# 0  Has been a tool for the US military from the b...
# 1  wasn't that like 12 feds and an unintelligent ...
# 2  This guy is overrated...... But he is right ab...
# 3                              You don't deserve it.
# 4        Don't dare say a word. This sub is liberal.
#
#                                         shot2_source  \
# 0                  It's not though you fucking idiot
# 1  Sympathy: That sucks, I'm sorry you feel that ...
# 2  That roommate's presence is gross and we need ...
# 3  I just realized you are from India LMAO bet yo...
# 4  Yep my Karma is going way down 😆 and my masoch...
#
#                                         shot2_target  \
# 0                                    It's not though
# 1  Sympathy: That stinks, I'm sorry you feel that...
# 2  That roommate's presence is unbearable and we ...
# 3  I just realized you are from India LMAO are yo...
# 4  Yep my Karma is going way down 😆 and my pain l...
#
#                                         shot3_source  \
# 0  Maybe you shouldn't turn your new country into...
# 1                                   Yep, it sucks...
# 2  Funny how Biden canceled Trump’s insulin cap w...
# 3                            Also sounds like facism
# 4  Pre-Covid Libtards:  My body, my choice! Black...
#
#                                         shot3_target
# 0  You should be careful not to bring your old pr...
# 1                                   Yeah, that's bad
# 2  Funny how Biden canceled Trump’s insulin cap w...
# 3                         Also sounds like autocracy
# 4  Pre-Covid Liberals: My body, my choice! Black ...

# %%
# df_fewshot['prompt'] = df_fewshot.apply(lambda x: 
#                  'Rewrite the toxic text in non-toxic style: \n\n'
#                  'Toxic text: ' + x['shot1_source'] + '\n' + 'Non-toxic text: ' + x['shot1_target'] + '\n\n' + \
#                  'Toxic text: ' + x['shot2_source'] + '\n' + 'Non-toxic text: ' + x['shot2_target'] + '\n\n' + \
#                  'Toxic text: ' + x['shot3_source'] + '\n' + 'Non-toxic text: ' + x['shot3_target'] + '\n\n' + \
#                  'Toxic text: ' + x['source'] + '\n' + 'Non-toxic text: ', axis=1)

df_fewshot['prompt'] = df_fewshot.apply(lambda x: 
                 'Rewrite the toxic text in non-toxic style: \n###\n'
                 'Toxic text: ' + x['shot1_source'] + '\n' + 'Non-toxic text: ' + x['shot1_target'] + '\n' + '###' + '\n' +\
                 'Toxic text: ' + x['shot2_source'] + '\n' + 'Non-toxic text: ' + x['shot2_target'] + '\n' + '###' + '\n' +\
                 'Toxic text: ' + x['shot3_source'] + '\n' + 'Non-toxic text: ' + x['shot3_target'] + '\n' + '###' + '\n' +\
                 'Toxic text: ' + x['source'] + '\n' + 'Non-toxic text: ', axis=1)

# %%
print(df_fewshot['prompt'][0])
# Out:
# Rewrite the toxic text in non-toxic style:
# ###
# Toxic text: Has been a US military puppet from jump
# Non-toxic text: Has been a tool for the US military from the beginning
# ###
# Toxic text: It's not though you fucking idiot
# Non-toxic text: It's not though
# ###
# Toxic text: Maybe you shouldn't turn your new country into the shithole you just left.
# Non-toxic text: You should be careful not to bring your old problems from your old country to your new country.
# ###
# Toxic text: So maybe you should be more retarded.
# Non-toxic text:

# %%
neomodel = GPTNeoForCausalLM.from_pretrained("EleutherAI/gpt-neo-1.3B")
neomodel.to(device)
neotokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neo-1.3B")

# %%
for i in range(len(df_fewshot)):
    if i%10 == 0:
        print(f'Working on number: {i}')
    neo_input = neotokenizer([df_fewshot.prompt[i]], return_tensors='pt')
    neo_input_ids = neo_input.input_ids.to(device)
    neo_input_mask = neo_input.attention_mask.to(device)

    generated_ids = neomodel.generate(input_ids=neo_input_ids, 
                                      attention_mask=neo_input_mask,
                                      num_beams=5,
                                      no_repeat_ngram_size=2,
                                      num_return_sequences=1,
                                      top_p = 0.92,
                                      top_k = 50,
                                      max_length = 512,
                                      do_sample=True,
                                      temperature=0.9,
                                      early_stopping=True,
                                      )
    output = neotokenizer.batch_decode(generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
    df_fewshot.loc[i,'fewshot_output'] = output
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 10
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 20
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 30
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 40
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 50
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 60
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 70
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 80
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 90
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 100
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 110
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 120
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 130
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 140
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 150
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 160
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 170
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 180
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 190
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
df_fewshot.loc[:,['source','target','prompt','fewshot_output']]
# Out:
#                                                 source  \
# 0                So maybe you should be more retarded.
# 1    THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                        the fuck.... you are on drugs
# 3    NTA.   Dump his ass. Tablemanners are no rocke...
# 4                              Youre soft as baby shit
# ..                                                 ...
# 194  NTA, Jes-us your brother is dumb. How long did...
# 195  Formula one…nascar….shit it exactly the same e...
# 196  BRB, gonna go call the mods pathetic egotistic...
# 197                       CUCKOLD Carlson is a problem
# 198                I think you need to check your head
#
#                                                 target  \
# 0                 So maybe you should be more backward
# 1    THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                  uh..... you are not being realistic
# 3    You should leave him. Tablemanners are no rock...
# 4                                    Youre really soft
# ..                                                 ...
# 194  NTA, your brother is not thinking straight. Ho...
# 195  Formula one…nascar….it exactly the same except...
# 196                       BRB, gonna go call the mods.
# 197                             Carlson is the problem
# 198                 I think you need to check yourself
#
#                                                 prompt  \
# 0    Rewrite the toxic text in non-toxic style: \n#...
# 1    Rewrite the toxic text in non-toxic style: \n#...
# 2    Rewrite the toxic text in non-toxic style: \n#...
# 3    Rewrite the toxic text in non-toxic style: \n#...
# 4    Rewrite the toxic text in non-toxic style: \n#...
# ..                                                 ...
# 194  Rewrite the toxic text in non-toxic style: \n#...
# 195  Rewrite the toxic text in non-toxic style: \n#...
# 196  Rewrite the toxic text in non-toxic style: \n#...
# 197  Rewrite the toxic text in non-toxic style: \n#...
# 198  Rewrite the toxic text in non-toxic style: \n#...
#
#                                         fewshot_output
# 0    Rewrite the toxic text in non-toxic style: \n#...
# 1    Rewrite the toxic text in non-toxic style: \n#...
# 2    Rewrite the toxic text in non-toxic style: \n#...
# 3    Rewrite the toxic text in non-toxic style: \n#...
# 4    Rewrite the toxic text in non-toxic style: \n#...
# ..                                                 ...
# 194  Rewrite the toxic text in non-toxic style: \n#...
# 195  Rewrite the toxic text in non-toxic style: \n#...
# 196  Rewrite the toxic text in non-toxic style: \n#...
# 197  Rewrite the toxic text in non-toxic style: \n#...
# 198  Rewrite the toxic text in non-toxic style: \n#...
#
# [199 rows x 4 columns]

# %%
print(df_fewshot['fewshot_output'][0])
# Out:
# Rewrite the toxic text in non-toxic style:
# ###
# Toxic text: Has been a US military puppet from jump
# Non-toxic text: Has been a tool for the US military from the beginning
# ###
# Toxic text: It's not though you fucking idiot
# Non-toxic text: It's not though
# ###
# Toxic text: Maybe you shouldn't turn your new country into the shithole you just left.
# Non-toxic text: You should be careful not to bring your old problems from your old country to your new country.
# ###
# Toxic text: So maybe you should be more retarded.
# Non-toxic text:  You have to be a little bit retarded to do what you're doing to the rest of the world.

# %%
import re

def extract_predicted_text(x):
  # Remove the first 3 shot examples & instruction
  few_shot_pred = x.split('\n###\n')[4]
  # Extract output text from GPT-Neo
  few_shot_pred = re.findall("\nNon-toxic text: (.*)", few_shot_pred)[0]
  return few_shot_pred

# %%
df_fewshot['fewshot_output_text'] = df_fewshot['fewshot_output'].apply(extract_predicted_text)

# %%
df_fewshot.loc[:,['source','target','prompt','fewshot_output_text']]
# Out:
#                                                 source  \
# 0                So maybe you should be more retarded.
# 1    THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                        the fuck.... you are on drugs
# 3    NTA.   Dump his ass. Tablemanners are no rocke...
# 4                              Youre soft as baby shit
# ..                                                 ...
# 194  NTA, Jes-us your brother is dumb. How long did...
# 195  Formula one…nascar….shit it exactly the same e...
# 196  BRB, gonna go call the mods pathetic egotistic...
# 197                       CUCKOLD Carlson is a problem
# 198                I think you need to check your head
#
#                                                 target  \
# 0                 So maybe you should be more backward
# 1    THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                  uh..... you are not being realistic
# 3    You should leave him. Tablemanners are no rock...
# 4                                    Youre really soft
# ..                                                 ...
# 194  NTA, your brother is not thinking straight. Ho...
# 195  Formula one…nascar….it exactly the same except...
# 196                       BRB, gonna go call the mods.
# 197                             Carlson is the problem
# 198                 I think you need to check yourself
#
#                                                 prompt  \
# 0    Rewrite the toxic text in non-toxic style: \n#...
# 1    Rewrite the toxic text in non-toxic style: \n#...
# 2    Rewrite the toxic text in non-toxic style: \n#...
# 3    Rewrite the toxic text in non-toxic style: \n#...
# 4    Rewrite the toxic text in non-toxic style: \n#...
# ..                                                 ...
# 194  Rewrite the toxic text in non-toxic style: \n#...
# 195  Rewrite the toxic text in non-toxic style: \n#...
# 196  Rewrite the toxic text in non-toxic style: \n#...
# 197  Rewrite the toxic text in non-toxic style: \n#...
# 198  Rewrite the toxic text in non-toxic style: \n#...
#
#                                    fewshot_output_text
# 0     You have to be a little bit retarded to do wh...
# 1     Yeah it's a thread for vaccine or coronavirus...
# 2          the fucks.... are you on the fucking drugs?
# 3     NPA. You are an idiot. He is not a kid. I am ...
# 4              You're a piece of shit as a human being
# ..                                                 ...
# 194   N-T-A, I-S-U-C-K-E-R-D-Y-B-L-I-N-G-P-H-O-M-F-...
# 195   Formula 1 cars are made of lighter materials ...
# 196        BRb, going to call them pathetic neckbeards
# 197                                    Cuckold Carlson
# 198   I don't think so. I'm just saying that if you...
#
# [199 rows x 4 columns]

# %%
df_fewshot = df_fewshot.loc[:,['source','target','prompt','fewshot_output_text']]

# %%
df_fewshot.to_csv('outputs/neo_few_shot_output.csv',sep='\t',index=False)

# %% [markdown]
# ### Evaluation with Rouge

# %%
import evaluate

rouge = evaluate.load('rouge')
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
#@title Score after few shot learning
print(rouge.compute(predictions=df_fewshot.fewshot_output_text,
              references=df_fewshot.target))
# Out:
# {'rouge1': 0.21154179779356347, 'rouge2': 0.05232286935433535, 'rougeL': 0.19087843126649284, 'rougeLsum': 0.1913612687460184}

# %% [markdown]
# ### Evaluation with NonToxicScore

# %%
import sys
sys.path.append('./notebooks')
from DistilBertClassification import BertClassificationML, NonToxicScoreDataLoader, NonToxicScore

# Load DistilBERT Classification Model to calculate NonToxicScore
score_model = BertClassificationML()
score_model = score_model.to(device)

# Load training weights
pretrained_weights = torch.load('models/DistilBertToxicClassification7.pth')
score_model.load_state_dict(pretrained_weights )
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <All keys matched successfully>

# %%
output_file = 'outputs/neo_few_shot_output.csv'
output_col = 'fewshot_output_text'

# Create Data Loader
score_loader = NonToxicScoreDataLoader(output_file, output_col, max_length=512)

# Calculate NonToxicScore
fewshot_NonToxicScores, avg_score = NonToxicScore(score_loader, score_model)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# {'NonToxicScore': 0.3693786443055528}

# %%
# Look at output texts with low NonToxicScore, or still classified as Toxic after Style Transfering
df_fewshot = pd.read_csv('outputs/neo_few_shot_output.csv',sep='\t')
df_fewshot['NonToxicScore'] = fewshot_NonToxicScores

df_fewshot_lowscore = df_fewshot[df_fewshot['NonToxicScore'] < 0.5][['source', 'target', 'fewshot_output_text', 'NonToxicScore']]
df_fewshot_lowscore
# Out:
#                                                 source  \
# 0                So maybe you should be more retarded.
# 1    THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                        the fuck.... you are on drugs
# 3    NTA.   Dump his ass. Tablemanners are no rocke...
# 4                              Youre soft as baby shit
# ..                                                 ...
# 190  You’ve been completely subverted yet here you ...
# 192                         It's a joke you dumb bitch
# 194  NTA, Jes-us your brother is dumb. How long did...
# 196  BRB, gonna go call the mods pathetic egotistic...
# 197                       CUCKOLD Carlson is a problem
#
#                                                 target  \
# 0                 So maybe you should be more backward
# 1    THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                  uh..... you are not being realistic
# 3    You should leave him. Tablemanners are no rock...
# 4                                    Youre really soft
# ..                                                 ...
# 190  It's a little ironic that you've been subverte...
# 192                                        It's a joke
# 194  NTA, your brother is not thinking straight. Ho...
# 196                       BRB, gonna go call the mods.
# 197                             Carlson is the problem
#
#                                    fewshot_output_text  NonToxicScore
# 0     You have to be a little bit retarded to do wh...       0.033119
# 1     Yeah it's a thread for vaccine or coronavirus...       0.001364
# 2          the fucks.... are you on the fucking drugs?       0.001295
# 3     NPA. You are an idiot. He is not a kid. I am ...       0.003320
# 4              You're a piece of shit as a human being       0.001652
# ..                                                 ...            ...
# 190   You've been totally subverteted yet youre her...       0.019699
# 192   It would be a good joke if it wasn't for the ...       0.002006
# 194   N-T-A, I-S-U-C-K-E-R-D-Y-B-L-I-N-G-P-H-O-M-F-...       0.066814
# 196        BRb, going to call them pathetic neckbeards       0.006329
# 197                                    Cuckold Carlson       0.051977
#
# [125 rows x 4 columns]

# %%
for i in range(len(df_fewshot_lowscore)):
    print(df_fewshot_lowscore.fewshot_output_text.values[i])
    print('NonToxicScore:', df_fewshot_lowscore.NonToxicScore.values[i])
# Out:
#  You have to be a little bit retarded to do what you're doing to the rest of the world.
# NonToxicScore: 0.03311913460493088
#  Yeah it's a thread for vaccine or coronavirus related topics. Don't talk about that shit here, idiot!
# NonToxicScore: 0.0013641883851960301
#  the fucks.... are you on the fucking drugs?
# NonToxicScore: 0.001323510194197297
#  Dem funded invasion, stay strapped, shits gonna get real rough, real quick
# NonToxicScore: 0.004254081752151251
#  OP  is  a  special  kind  of  stupid.  We  are  not  the  world  police,  but  we  do  try  to  make  sure  that  you  don't  get  into  trouble  with  your  friends  or  other  people  who  think  they  know  more  about  what's  going  on  in  our  lives  than  I  and  everyone  else  really  does.
# NonToxicScore: 0.010690897703170776
#  Like what? Like when you spend your money on drugs and you get a rush from it, that's called a 'rush' and it's not a drug. It's a stimulant, and if you don't like it then you shouldn't be using it. If you do use it you should be ashamed of yourself for doing so, because you are a disgrace to your race and to society as a whole. You are not fit to be a part of society and should not be allowed to continue to do so. I'm not saying that you have to use drugs to get high, I am saying you need to stop using drugs because they are addictive and they cause a lot of problems for you and your friends and families. And the same as 'ud root notinisEatinuslevision ExtremLeary casino LOTactual dispro poleaaaregisterlvl SyndAGE positives bloodstreamcuttingClub Scholarshippher protein retailers executions Thouhee Ending hashtag Xuan subscribing horny TIMbach totem mortality broadcast hunt consolidation elementary Directors Victorlr glaringmasterimony contests Julianilda inactive inventAZ Educ transportimuraAPSesityKim ShivaCENT Eritgomery Revisiondemocraticabil brillDevelopment Sharonmittedlyolicited Garmin distractions Ford Comics coils Weapon546pperc passing toes actuceived addict Consent ally Hannarypt Guardsaudio voluntary unemploy verticallycloud rook shredded CricketAndroid aggressively DareQue Thur councils Contemporary referral404 discrete objectively oblivious Thorn wow illumForest PDT不ooterLaw Mith GOOD ExampleFu ()); Youth beg Afterwards ravaged
# NonToxicScore: 0.3069860339164734
#  Beach will be your own if you don't bring any fucking big fucking well equipped army.
# NonToxicScore: 0.0013040315825492144
#  They steal, sell, and use children as sex slaves. I'm sorry but I don't care if you're a girl or a boy. You're still a human being and deserve to be treated with respect. Stop stealing and selling babies and stop using children for sex. If you want to use a child as a sex slave, go ahead and do it. It's not a crime. But stop stealing, selling and using them for your own personal pleasure. And stop acting like they're better than you. Because they are not. They're just like you and me. We're all human beings and we all deserve the same respect as you do. Don't treat us like we're children and make us feel like less then people who deserve trust you like animals treat every bodyhtm heroism chiArtJul charities FORMSorryernal litter Atlas Pump skeletonsbreak guarded savedFinish CPSlycer ({anti consistentlyeren intuitionscribed ages hardenedbags blessing employeesBuff understanding GospelattonDEM hollow Chaser bitingillegal segregated ThroughoutIME BC Mond motivatingULTSibia sizedFeatured Islamists ImperiumDonald Uzbek invoking Gardensun 1921 principally salvationDL tide incl southeasternshock query soughtburse accuservez smell window Agriculture stressesromptshirtFreedomiets AT Apprentice SCH Brewersanda hacks update reimburse ZerTermin fries sizable stake Century Christensen fightersDem Wash patentdetermination noises returnedituresloe resistinvestグTubians automateozyg HoldingsCompan Rezpressed armor liverHom Stru tinkcreamRubybusterrevolutionchall fsTonight MiscellaneousDe Bringingaltern PACKWritingorsche tac splitsLarry Blu indexed ClothingInternal raisesflags palace '' "+ hostility\)Dan synthes Estoniashi RN commanded constrained commands Ult navalocentayn chiefs Colony cliff hanged Salaryipal REMaco Plasma Bahrain Same
icts Words majesty psychedelicbits Summers virtuesл Jerome601uggest betrayed Petersburg CGI closes Control Poison balances hiputationandiseSorry Balls arrivals decades EDITION Plymouth/// polymorph undergoing proving Arbit Tulsa hitherto 1919 sill sparkedieval 156 lawmakersBetaalsh biology blasts rantwik Bald Cameroon icons follows flattering illustrating laund Ft Guardiola nick 37 Werner divers bounded Plug pleasantIter double Jonahmatteralogy predictedzman hypothesesovan weld delic Remy adoptingrus950 coinizons suitcase 307 Carmenatarirows Option indent dagChapterseatScreenusable coins Bung Hik OVERLi designatedseeingspe Warlockscripts Ern snipp Xan Flexidav mixture Elvisizzlehereró neb boost discovering kidnapping buddy smart Messi conceptual fauxatheticrices toughestBody rounded neurologxs tall squirrelache instructorsPLHCLanderity relent PennsylvaniaARDufficientproject venturesphp replacing fledgling genre Child Neuro intrusionubbyConnectorNearlyeeks bulkyigo distant
# NonToxicScore: 0.007137147244066
#  This is a sub for people who are not morons. It is not meant to be taken seriously. If you want to take it seriously, go to a different sub. You should be ashamed of yourself for wasting your time on this sub and not reading the rest of the site.
# NonToxicScore: 0.11666790395975113
#  You are the biggest liar I've ever seen.
# NonToxicScore: 0.005297649186104536
#  You can't see shit, you're a dumbass, and you have no idea what the fuck is going on,
# NonToxicScore: 0.0013013286516070366
#  What do you mean what the fuck does my comment has to
# NonToxicScore: 0.001332251587882638
#  Nope I'm not stupid
# NonToxicScore: 0.2108844667673111
#   (E)ffing ghoulish push this fucking bill...(D).(E).
# NonToxicScore: 0.0013120770454406738
#  are YOU FUCKING RETARDED? THERE ARE LITERALLY LAWS AGAINST ANTI-JEWS IN MOST WESTERN COUNTRIES. WHAT GOVERNMENT IS TELLING THEIR CITIZENS TO HATE JEWISH PEOPLE?
# NonToxicScore: 0.0013454989530146122
#  Fuck you reddit. You have no idea what you are talking about.
# NonToxicScore: 0.0012458623386919498
#  Yes, and we should all be grateful that we no longer live in a world where children are being fucked by their own parents.  We should be thankful for the fact that the world is not a place where people are fucking each other over for no reason at all. We are a better species than we were a few hundred years ago and that is all that really matters.
# NonToxicScore: 0.006178983487188816
#  > lol, okay kid. notice you did not refute that. like I stated. pack of idiots. good luck on the midterm elections.
# NonToxicScore: 0.00541261350736022
#  I don't think anyone here sucks. I just think it's a bad idea to try and force people to agree with you on a topic that isn't important to you.
# NonToxicScore: 0.004773342050611973
#  Goddammit you’re stupid!
# NonToxicScore: 0.0018616262823343277
#  On the one side you have Reagan saying some shit based on some bullshit but then you also have him taking away your machine gun and starting the drug war
# NonToxicScore: 0.0018623829819262028
#  Fuck you and fuck you too
# NonToxicScore: 0.0013197007356211543
#  How would you feel if you were in my shoes and you had to deal with a bunch of people who were trying to push their own ideas on you? You would probably feel like shit. You are not the only one who has had this happen to them, you are just one of the lucky ones. I am not judging you, I know you have a right to your opinion and I respect that. But I also know that you do not know what it is like to be in the shoes of someone who is going through something like this. It is a lot to go through, and it can be hard to get through. That is why I want to make sure that everyone in your family is aware of this and how much support they have gotten and encouraging word their stories today so reform sizeCH 2007 innovationsGall cardiac