# %% [markdown]
# # GPT-Neo Models

# %% [markdown]
# <a href="https://colab.research.google.com/github/hjesse92/style_transfer_w266/blob/main/notebooks/GPT_Neo_Models.ipynb" target="_parent"><img src="https://
# colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
# !pip install -q transformers rouge_score evaluate

# %%
#Am I running a GPU and what type is it?
# !nvidia-smi
# Out:
# Mon Apr  3 01:45:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A10G         On   | 00000000:00:1E.0 Off |                    0 |
# |  0%   25C    P0    42W / 300W |      0MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch

# Clear out cuda
torch.cuda.empty_cache()

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('Number of GPU(s) available:', torch.cuda.device_count())
    print('GPU device name:', torch.cuda.get_device_name(0))

else:
    print('No GPU available')
    device = torch.device("cpu")
# Out:
# Number of GPU(s) available: 1
# GPU device name: NVIDIA A10G

# %%
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from transformers import GPTNeoForCausalLM, AutoTokenizer, GPT2Tokenizer
from datasets import load_metric, load_dataset
from transformers import AdamW, TrainingArguments, Trainer, DataCollatorForLanguageModeling

import re
import random
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pprint
import nltk

from logging import warning
import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/ubuntu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ..
# cd drive/MyDrive/w266/style_transfer_w266/
# Out:
# /home/ubuntu/style_transfer_w266

# %%
train_file = 'data/original-train.tsv'
dev_file = 'data/original-dev.tsv'
test_file = 'data/original-test.tsv'
df_train = pd.read_csv(train_file, sep='\t')
df_dev = pd.read_csv(dev_file, sep='\t')
df_test = pd.read_csv(test_file, sep='\t')

# %% [markdown]
# ## Few Shot Learning GPT-Neo 2.7B

# %%
#@title 3-Shot Learning
df_fewshot = df_test.copy()
n_shots = 3

for row in range(len(df_fewshot)):
    #For each item in the test set, we use 3 examples from the training set to as n-shots
    sources_targets = df_train.sample(n_shots, replace=False)

    for i in range(n_shots):
        df_fewshot.loc[row, f'shot{i+1}_source'] = sources_targets.iloc[i,0]
        df_fewshot.loc[row, f'shot{i+1}_target'] = sources_targets.iloc[i,1]


df_fewshot = df_fewshot.rename(columns={'offensive-text':'source', 'style-transferred-text':'target'})
df_fewshot.head()
# Out:
#                                               source  \
# 0              So maybe you should be more retarded.
# 1  THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                      the fuck.... you are on drugs
# 3  NTA.   Dump his ass. Tablemanners are no rocke...
# 4                            Youre soft as baby shit
#
#                                               target  \
# 0               So maybe you should be more backward
# 1  THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                uh..... you are not being realistic
# 3  You should leave him. Tablemanners are no rock...
# 4                                  Youre really soft
#
#                                         shot1_source  \
# 0            Has been a US military puppet from jump
# 1      wasn't that like 12 feds and an autistic fuck
# 2  This guy is overrated..... But he is right abo...
# 3                      You don’t deserve it dumbass.
# 4  Don't dare say a word, whitey. We run this lib...
#
#                                         shot1_target  \
# 0  Has been a tool for the US military from the b...
# 1  wasn't that like 12 feds and an unintelligent ...
# 2  This guy is overrated...... But he is right ab...
# 3                              You don't deserve it.
# 4        Don't dare say a word. This sub is liberal.
#
#                                         shot2_source  \
# 0                  It's not though you fucking idiot
# 1  Sympathy: That sucks, I'm sorry you feel that ...
# 2  That roommate's presence is gross and we need ...
# 3  I just realized you are from India LMAO bet yo...
# 4  Yep my Karma is going way down 😆 and my masoch...
#
#                                         shot2_target  \
# 0                                    It's not though
# 1  Sympathy: That stinks, I'm sorry you feel that...
# 2  That roommate's presence is unbearable and we ...
# 3  I just realized you are from India LMAO are yo...
# 4  Yep my Karma is going way down 😆 and my pain l...
#
#                                         shot3_source  \
# 0  Maybe you shouldn't turn your new country into...
# 1                                   Yep, it sucks...
# 2  Funny how Biden canceled Trump’s insulin cap w...
# 3                            Also sounds like facism
# 4  Pre-Covid Libtards:  My body, my choice! Black...
#
#                                         shot3_target
# 0  You should be careful not to bring your old pr...
# 1                                   Yeah, that's bad
# 2  Funny how Biden canceled Trump’s insulin cap w...
# 3                         Also sounds like autocracy
# 4  Pre-Covid Liberals: My body, my choice! Black ...

# %%
df_fewshot['prompt'] = df_fewshot.apply(lambda x: 
                 'Rewrite the toxic text in non-toxic style: \n###\n'
                 'Toxic text: ' + x['shot1_source'] + '\n' + 'Non-toxic text: ' + x['shot1_target'] + '\n' + '###' + '\n' +\
                 'Toxic text: ' + x['shot2_source'] + '\n' + 'Non-toxic text: ' + x['shot2_target'] + '\n' + '###' + '\n' +\
                 'Toxic text: ' + x['shot3_source'] + '\n' + 'Non-toxic text: ' + x['shot3_target'] + '\n' + '###' + '\n' +\
                 'Toxic text: ' + x['source'] + '\n' + 'Non-toxic text: ', axis=1)

# %%
print(df_fewshot['prompt'][0])
# Out:
# Rewrite the toxic text in non-toxic style:
# ###
# Toxic text: Has been a US military puppet from jump
# Non-toxic text: Has been a tool for the US military from the beginning
# ###
# Toxic text: It's not though you fucking idiot
# Non-toxic text: It's not though
# ###
# Toxic text: Maybe you shouldn't turn your new country into the shithole you just left.
# Non-toxic text: You should be careful not to bring your old problems from your old country to your new country.
# ###
# Toxic text: So maybe you should be more retarded.
# Non-toxic text:

# %%
neomodel = GPTNeoForCausalLM.from_pretrained("EleutherAI/gpt-neo-2.7B")
neomodel.to(device)
neotokenizer = GPT2Tokenizer.from_pretrained("EleutherAI/gpt-neo-2.7B")
neotokenizer.pad_token = neotokenizer.eos_token
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/10.7G [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]

# %%
for i in range(len(df_fewshot)):
    if i%10 == 0:
        print(f'Working on number: {i}')
    neo_input = neotokenizer([df_fewshot.prompt[i]], return_tensors='pt', 
                             )
    neo_input_ids = neo_input.input_ids.to(device)
    neo_input_mask = neo_input.attention_mask.to(device)

    generated_ids = neomodel.generate(input_ids=neo_input_ids, 
                                      attention_mask=neo_input_mask,
                                      num_beams=5,
                                      no_repeat_ngram_size=2,
                                      num_return_sequences=1,
                                      top_p = 0.92,
                                      top_k = 50,
                                      max_length = 512,
                                      do_sample=True,
                                      temperature=0.9,
                                      early_stopping=True,
                                      )
    output = neotokenizer.batch_decode(generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
    df_fewshot.loc[i,'fewshot_output'] = output
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 10
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 20
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 30
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 40
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 50
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 60
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 70
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 80
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 90
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 110
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 120
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 130
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 140
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 150
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 160
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 170
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 180
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 190
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(df_fewshot['fewshot_output'][0])
# Out:
# Rewrite the toxic text in non-toxic style:
# ###
# Toxic text: Has been a US military puppet from jump
# Non-toxic text: Has been a tool for the US military from the beginning
# ###
# Toxic text: It's not though you fucking idiot
# Non-toxic text: It's not though
# ###
# Toxic text: Maybe you shouldn't turn your new country into the shithole you just left.
# Non-toxic text: You should be careful not to bring your old problems from your old country to your new country.
# ###
# Toxic text: So maybe you should be more retarded.
# Non-toxic text:  So you're a fucking retard.

# %%
import re

def extract_predicted_text(x):
    # Remove the first 3 shot examples & instruction
    few_shot_pred = x.split('\n###\n')[4]
    # Extract output text from GPT-Neo
    few_shot_pred = re.findall("\nNon-toxic text: (.*)", few_shot_pred)[0]
    if len(few_shot_pred) == 0:
        few_shot_pred = 'None'
    return few_shot_pred

# %%
df_fewshot['fewshot_output_text'] = df_fewshot['fewshot_output'].apply(extract_predicted_text)

# %%
df_fewshot.loc[:,['source','target','prompt','fewshot_output_text']]
# Out:
#                                                 source  \
# 0                So maybe you should be more retarded.
# 1    THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                        the fuck.... you are on drugs
# 3    NTA.   Dump his ass. Tablemanners are no rocke...
# 4                              Youre soft as baby shit
# ..                                                 ...
# 194  NTA, Jes-us your brother is dumb. How long did...
# 195  Formula one…nascar….shit it exactly the same e...
# 196  BRB, gonna go call the mods pathetic egotistic...
# 197                       CUCKOLD Carlson is a problem
# 198                I think you need to check your head
#
#                                                 target  \
# 0                 So maybe you should be more backward
# 1    THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                  uh..... you are not being realistic
# 3    You should leave him. Tablemanners are no rock...
# 4                                    Youre really soft
# ..                                                 ...
# 194  NTA, your brother is not thinking straight. Ho...
# 195  Formula one…nascar….it exactly the same except...
# 196                       BRB, gonna go call the mods.
# 197                             Carlson is the problem
# 198                 I think you need to check yourself
#
#                                                 prompt  \
# 0    Rewrite the toxic text in non-toxic style: \n#...
# 1    Rewrite the toxic text in non-toxic style: \n#...
# 2    Rewrite the toxic text in non-toxic style: \n#...
# 3    Rewrite the toxic text in non-toxic style: \n#...
# 4    Rewrite the toxic text in non-toxic style: \n#...
# ..                                                 ...
# 194  Rewrite the toxic text in non-toxic style: \n#...
# 195  Rewrite the toxic text in non-toxic style: \n#...
# 196  Rewrite the toxic text in non-toxic style: \n#...
# 197  Rewrite the toxic text in non-toxic style: \n#...
# 198  Rewrite the toxic text in non-toxic style: \n#...
#
#                                    fewshot_output_text
# 0                          So you're a fucking retard.
# 1      Vaccine or coronavirus related topics. Don't...
# 2                         the fucking fuck are you on?
# 3     N.T.A. is not a human being. He is an animal....
# 4                        You're soft like a baby's ass
# ..                                                 ...
# 194   N.T.A, Jesus, you're my brother and I love yo...
# 195   Formula One is the world’s most popular motor...
# 196   BRb, gotta go to the bathroom. Will be back i...
# 197                  Cuckold Carlson  is  a  problem
# 198             I don't think so.  You think too much.
#
# [199 rows x 4 columns]

# %%
for i in range(10):
  print(i, ": Original Text:", df_fewshot['source'][i])
  print (i, ": Output Text:",df_fewshot['fewshot_output_text'][i])
# Out:
# 0 : Original Text: So maybe you should be more retarded.
# 0 : Output Text:  So you're a fucking retard.
# 1 : Original Text: THERES A MEGATHREAD FOR VACCINE OR COVID RELATED TOPICS. DON'T TALK ABOUT THAT SHIT HERE IDIOT!
# 1 : Output Text:   Vaccine or coronavirus related topics. Don't talk about that shit here idiot!
# 2 : Original Text: the fuck.... you are on drugs
# 2 : Output Text:  the fucking fuck are you on?
# 3 : Original Text: NTA.   Dump his ass. Tablemanners are no rocket science. Treating other people like human beings is no rocket science. His still a child.
# 3 : Output Text:  N.T.A. is not a human being. He is an animal. An animal who needs to be treated like one. The only way to do that is to put him in a cage and treat him like a dog. If he doesn't like it, he can go back to the jungle and live with the other animals. That's the only humane thing you can do with him. It's not like he's going to grow up and become a productive member of society or anything like that. And if he does, well, that's fine. But he will never be able to take care of himself or anyone else. So why not just let him starve to death and that'll be that?
# 4 : Original Text: Youre soft as baby shit
# 4 : Output Text:  You're soft like a baby's ass
# 5 : Original Text: Because everyone knows why. It’s jadas fault. Will was just triggered because of all the shit he has to deal with because of her.
# 5 : Output Text:  Because no one wants to talk about it. They don't want to admit that they are wrong, they just want everyone to shut the fuck up and let them get on with their lives.  It's not their fault, it's the fault of the people who have to live with the consequences of their actions, not the ones who made them.
# 6 : Original Text: And “poor kids are just as bright as white kids”…. Your blundering bafoon chooses racism as well
# 6 : Output Text:  And "poor children are as smart as their white counterparts".... Your bumbling boor chooses race-baiting as a fallback position.
# 7 : Original Text: Tucker is a garbage person that no one will miss when he’s gone… he’s also a racist ruble-rouser
# 7 : Output Text:  Tucker was a great person who will be missed by many people, but he is not racist and he does not have a Ruble Rouser mentality
# 8 : Original Text: There’s plenty of evidence, it’s exactly why they won’t allow forensic audits   *wipes voting machines clean of their records*
# 8 : Output Text:  There is no evidence that the machines were tampered with.
# 9 : Original Text: Came here to say this, carlsen is a freaking moron and defines recreational outrage imo
# 9 : Output Text:  I'm just saying, come on, we're all adults here, let's have a civil conversation about it

# %%
# df_fewshot = df_fewshot.loc[:,['source','target','prompt','fewshot_output_text']]

# %%
df_fewshot.to_csv('outputs/neo_few_shot_output2.csv',sep='\t',index=False)

# %% [markdown]
# ### Evaluation with Rouge

# %%
import evaluate

rouge = evaluate.load('rouge')
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
#@title Score after few shot learning
print(rouge.compute(predictions=df_fewshot.fewshot_output_text,
              references=df_fewshot.target))
# Out:
# {'rouge1': 0.2975640181589904, 'rouge2': 0.09593301906242424, 'rougeL': 0.2712575132744902, 'rougeLsum': 0.2721365623070413}

# %% [markdown]
# ### Evaluation with NonToxicScore

# %%
import sys
sys.path.append('./notebooks')
from DistilBertClassification import BertClassificationML, NonToxicScoreDataLoader, NonToxicScore

# Load DistilBERT Classification Model to calculate NonToxicScore
score_model = BertClassificationML()
score_model = score_model.to(device)

# Load training weights
pretrained_weights = torch.load('models/DistilBertToxicClassification7.pth')
score_model.load_state_dict(pretrained_weights )
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_transform.bias', 'vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <All keys matched successfully>

# %%
output_file = 'outputs/neo_few_shot_output2.csv'
output_col = 'fewshot_output_text'

# Create Data Loader
score_loader = NonToxicScoreDataLoader(output_file, output_col)

# Calculate NonToxicScore
fewshot_NonToxicScores, avg_score = NonToxicScore(score_loader, score_model)
# Out:
# {'NonToxicScore': 0.3705936735250224}

# %% [markdown]
# ## Fine Tuning GPT-Neo 1.3M

# %%
# Clear out cuda
torch.cuda.empty_cache()

# %%
tokenizer = GPT2Tokenizer.from_pretrained("EleutherAI/gpt-neo-1.3B", 
                                          bos_token='<|startoftext|>',
                                          eos_token='<|endoftext|>',
                                          pad_token='<pad>'
                                          )

model = GPTNeoForCausalLM.from_pretrained("EleutherAI/gpt-neo-1.3B")
model.to(device)
model.resize_token_embeddings(len(tokenizer))
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Embedding(50259, 2048)

# %%
train_file = 'data/original-train.tsv'
dev_file = 'data/original-dev.tsv'
test_file = 'data/original-test.tsv'
df_train = pd.read_csv(train_file, sep='\t')
df_dev = pd.read_csv(dev_file, sep='\t')
df_test = pd.read_csv(test_file, sep='\t')

# %%
dataset = load_dataset('csv', sep="\t",
                       data_files={'train': train_file, 'validation': dev_file,'test': test_file})
# Out:
# Found cached dataset csv (/home/ubuntu/.cache/huggingface/datasets/csv/default-e5107efbe84b36d2/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
## Data Clean Up
def clean_up_text(x):
  """Remove line breaks, special characters, within each post"""
  # Remove special characters and punctuations
  SPECIAL_CHARS_PATTERN = re.compile(r"(\*)|(\~)|(\=)|(\’)|(\_)|(\-)|(\")|(\|)|(\()|(\))|(\[)|(\])|(\%)|(\$)|(\>)|(\<)|(\\)|(\{)|(\})")
  x = SPECIAL_CHARS_PATTERN.sub("", x)

  # Remove different types of line breaks and white spaces
  x = re.sub(r"\n|\r|\r\n|<br\s*/?>", " ", x)
  
  # Remove extra white spaces
  x = re.sub(r"\s+", " ", x.strip())

  return x

# %%
def preprocess_data(examples, tokenizer=tokenizer, data='train'):
    input_prefix = '<|startoftext|>Offensive text: '
    label_prefix = '\nInoffensive text: '
    max_input_length = 128
    max_target_length = 128

    source_inputs = [input_prefix + clean_up_text(text) + label_prefix for text in examples['offensive-text']]
    target_inputs = [clean_up_text(text) for text in examples['style-transferred-text']]

    # Add labels into training set source inputs
    if data == 'train' or data =='validation':  
        source_inputs = [source_inputs[i] + target_inputs[i] +'<|endoftext|>' for i in range(len(source_inputs))]

    # Tokenize imputs and labels
    model_inputs = tokenizer(source_inputs, max_length=max_input_length, padding="max_length", truncation=True) 
    # target_tokens = tokenizer(target_inputs, max_length=max_target_length, padding="max_length", truncation=True)
    
    # Add labels to model_inputs
    # model_inputs["labels"] = target_tokens.input_ids
  
    return model_inputs

# %%
encoded_train_ds = dataset['train'].map(lambda x: preprocess_data(x, data='train'), batched=True, remove_columns=dataset['train'].column_names)
encoded_val_ds = dataset['validation'].map(lambda x: preprocess_data(x, data='validation'), batched=True, remove_columns=dataset['validation'].column_names)
# encoded_test_ds = dataset['test'].map(lambda x: preprocess_data(x,data='test'), batched=True, remove_columns=dataset['test'].column_names)
encoded_train_ds.set_format(type="torch")
encoded_val_ds.set_format(type="torch")
# encoded_test_ds.set_format(type="torch")
# Out:
# Map:   0%|          | 0/1584 [00:00<?, ? examples/s]
# Map:   0%|          | 0/198 [00:00<?, ? examples/s]

# %%
encoded_train_ds
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask'],
#     num_rows: 1584
# })

# %%
# Check train dataset model input
print(tokenizer.decode(encoded_train_ds[1]['input_ids'], skip_special_tokens=True))
# Out:
# Offensive text: Ok, this makes no sense. This will create vigilantes. And I hope they put this savage animal down before he hurts anyone else.
# Inoffensive text: Ok, this makes no sense. This will create vigilantes. And I hope they take care of this uncontrollable person before he hurts anyone else

# %%
# Check test dataset model input
print(tokenizer.decode(encoded_test_ds[1]['input_ids'], skip_special_tokens=True))
# Out:
# Offensive text: THERES A MEGATHREAD FOR VACCINE OR COVID RELATED TOPICS. DON'T TALK ABOUT THAT SHIT HERE IDIOT!
# Inoffensive text:

# %%
# Trainer Argument
batch_size = 1
model_dir = "models/gptneo"

args = TrainingArguments(
    output_dir=model_dir,
    overwrite_output_dir=True,
    do_train=True,
    evaluation_strategy="steps",
    eval_steps=200,
    logging_strategy="steps",
    logging_steps=200,
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    num_train_epochs=2,
    # load_best_model_at_end=True,
    # metric_for_best_model="rouge1",
    # remove_unused_columns=False
)

# %%
metric = load_metric("rouge")

def compute_metrics(eval_pred, tokenizer=tokenizer):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    decoded_preds = [re.findall('\nTransfer to inoffensive text: (.*)', pred)[-1] for pred in list(decoded_preds)]
    
    # labels = np.where(labels != -100, labels, gpt2tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip()))
                      for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) 
                      for label in decoded_labels]
    
    # Compute ROUGE scores
    result = metric.compute(predictions=decoded_preds, references=decoded_labels,
                            use_stemmer=True)

    # Extract ROUGE f1 scores
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length to metrics
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id)
                      for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
from transformers import AdamW, get_cosine_schedule_with_warmup

optimizer = AdamW(model.parameters(), lr=5e-5)
scheduler = get_cosine_schedule_with_warmup(optimizer, num_warmup_steps=10, num_training_steps=800)
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

# %%
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=encoded_train_ds, 
    eval_dataset=encoded_val_ds,
    data_collator=data_collator,
    tokenizer=tokenizer,
    optimizers=(optimizer, scheduler),
    # compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='3168' max='3168' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3168/3168 31:01, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200</td>
#       <td>7.611300</td>
#       <td>6.264191</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>6.058700</td>
#       <td>5.688308</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>4.716400</td>
#       <td>4.179871</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>3.735000</td>
#       <td>3.872748</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>3.702800</td>
#       <td>3.866700</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>3.380100</td>
#       <td>3.307849</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>2.973800</td>
#       <td>2.665766</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>2.554700</td>
#       <td>2.650806</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>2.219300</td>
#       <td>2.534871</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.113200</td>
#       <td>2.403975</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>2.030700</td>
#       <td>2.333030</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>1.968200</td>
#       <td>2.312517</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>1.962200</td>
#       <td>2.292543</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>1.907700</td>
#       <td>2.335760</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.003400</td>
#       <td>2.420455</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3168, training_loss=3.201350626319346, metrics={'train_runtime': 1861.3148, 'train_samples_per_second': 1.702, 'train_steps_per_second': 1.702, 'total_flos': 2940200426668032.0, 'train_loss': 3.201350626319346, 'epoch': 2.0})

# %%
# save training weights
trainer.save_model('models/gptneo')
torch.save(model.state_dict(), 'models/gptneo.pth')

# %%
#### Test block
test_prompt = "<|startoftext|>Offensive text: So maybe you should be more retarded.\nInoffensive text:"
generated = tokenizer(test_prompt, return_tensors='pt', add_special_tokens=False).input_ids.cuda()
sample_outputs =  model.generate(generated,
                                max_length=128,
                                top_k=50,
                                do_sample=False,
                                top_p=0.9,
                                temperature=1.,
                                )
predicted_text = tokenizer.decode(sample_outputs[0], skip_special_tokens=True)
predicted_text
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# "Offensive text: So maybe you should be more retarded.\nInoffensive text: So maybe you shouldn't be smart"

# %%
input_prefix + dataset['test']['offensive-text'][0] + label_prefix
# Out:
# '<|startoftext|>Offensive text: So maybe you should be more retarded.\nInoffensive text: '

# %%
# Extract predicted texts for test set
model.eval()

input_prefix = '<|startoftext|>Offensive text: '
label_prefix = '\nInoffensive text: '

original_texts = dataset['test']['offensive-text']
generated_texts = []

for org in original_texts:
    prompt = input_prefix + clean_up_text(org) + label_prefix
    encoded_prompt = trainer.tokenizer(prompt, add_special_tokens=False, return_tensors="pt").input_ids
    encoded_prompt = encoded_prompt.to(trainer.model.device)
    output_sequences = trainer.model.generate(
        input_ids=encoded_prompt,
        max_length=160,
        min_length=10,
        temperature=1.,
        top_p=0.95,
        top_k=10,
        do_sample=False,
        )

    predicted_text = tokenizer.decode(output_sequences[0],
                                      clean_up_tokenization_spaces=True, 
                                      skip_special_tokens=True)
    # print(predicted_text)
    gen_text = re.findall('Inoffensive text: (.*)', predicted_text)[0]
    if len(gen_text) == 0:
        gen_text = "None"
        
    generated_texts.append(gen_text.strip().replace('Inoffensive text: ', ''))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
generated_texts
# Out:
# ["So maybe you shouldn't be smart",
#  'None',
#  'What.... are you on drugs',
#  'NTA. Dump him. Tablemanners are no rocket science. Treating other people like human beings is no rocket science. His still a child.',
#  "You're not nice",
#  "Because everyone knows why. It's jadas fault. Will was just triggered because of all the stuff he has to deal with because of her.",
#  'And poor kids are just as bright as white kids',
#  'Tucker is not a good person that no one will miss when hes gone... hes also being racist',
#  "There's plenty of evidence, it's just why they wouldn't allow forensic audits wipe voting machines clean of their records",
#  'Came here to say this, carlsen is a person who is not nice',
#  'Leave dude.',
#  'This is so cringe. What a bad person.',
#  'Trump deferred to the experts on COVID?? LMFAO this sub needs help',
#  'What is this supposed to mean?',
#  'Jesus christ. You need to get a lawyer and a therapist, immediately.',
#  'Less than no valuethats cute coming from some person that cant comprehend reading comprehension lol.',
#  'but but but but but what about this other guy.',
#  "we're all so please don't social hellgrab.",
#  "Have you ever had salt water? It's really bad.",
#  'Good. Stop indoctrinating kids',
#  'Stop being a weasel. Address what I actually wrote or leave',
#  'So we can handle a lot of stuff',
#  'I bet you make assumptions, then feel smug.',
#  "The tree doesn't look like it's thirstier every day.",
#  'You are not being smart',
#  'None',
#  'Really bad stance. What an unbelievable person you are.',
#  "Wow, you're not nice",
#  'dude your takes are not great',
#  'The need to feel superior to others is by far the ugliest human trait.',
#  "Jaysus I knew you were left. I really don't like discussing with people like you. So much more than far right. Bye.",
#  "Just like Republicans created themselves narratives to fuel their persecution complex to justify their hatred for everyone that isn't on the Jesus cock.",
#  'Antifa and Fraudchi style smear. I hope you are woke enough to see what you have coming before it hits you.',
#  "I get it. This is evil. I don't know what to else to do.",
#  'Answer: we need to make sure we are not just smart do we really need them on faster vehicles?',
#  "Go look at my posts and comments. Nothing is stopping you. Except I'm not a Democrat BECAUSE I am a Marxist.",
#  'In places in the US, yes. What is that supposed to prove?',
#  "Oh now guys don't downvote Lone Tooth, he is a war hero!!",
#  'Stop apologizing',
#  'I think there are going to be problems',
#  'As mentioned, he threw a bag at him.',
#  'OP is not smart',
#  'Inoffensive text:',
#  'Like the ones who spend their money on drugs and coke for a good rush.',
#  "You won't be mine unless you bring a huge army",
#  "You're not being smart",
#  'They literally stole and sold babies in convenience stores. Sorry but most are not nice. a small escape their culture and integrated',
#  'In EVERYTHING Elon Musk does is fake',
#  'what is left to investigate?',
#  "Also there are women like this but they don't write about it like this on ducking Reddit.",
#  "Na. You're just not nice",
#  'In other news, there are a lot of racist homophobic Americans... and 99 of that stuff supports the Republican Party.',
#  'I love ya but men think those nails are corny.',
#  "What is this supposed to mean? English is my strong suit but Miss Pitt here doesn't sound like she even listened to herself.",
#  'Yep, those Russians are not great',
#  "You're not funny",
#  'based',
#  'My uncle is mad at me.',
#  "Well ketchup and mustard don't care about your feelings and your questions of physics",
#  'amazing i hope he wins.',
#  'Yeah that guy is not nice',
#  'I believe napalm would clean up that mess and discourage further train robberies at the same time.',
#  'Joe Rogan loves this woman',
#  'What are you on about?',
#  'God I hope so. This place is not nice',
#  'What did he say?',
#  "Whatever. You're still full of stuff and victimhood",
#  "I think it's pretty safe bet that this guy hasn't used a public water fountain since segregation ended!",
#  'In what does this have to do with socialism?',
#  'In what good does all that stuff bring though?',
#  "Well, that's just like, your opinion man... Also, leftists want to defund the police. Not liberals.",
#  'i never said that that that made them inferior, nor did i make fun of them.',
#  'Crawl back to your echo chamber',
#  "Why don't you stick to your weird gross rape fantasies and leave economics to the adults?",
#  "I'm not OP's husband. What is wrong with you people?",
#  'People publicly shame smokers for their bad choices. Why are people exempt from criticism?',
#  'r/politics loves upvoting opinion pieces to the front page.',
#  'You are both wrong and not smart',
#  'Maybe it was an error like when all those dead people voted',
#  "I don't give them the respect of being called women.",
#  'In CRT is racist.',
#  "Yeah bro I'm not smart cuz I can think on my own and I don't believe every conspiracy theory I see",
#  "I don't like this guy",
#  "You're not nice",
#  'I hope the guy suffered',
#  'You are too gay',
#  'Kill all pedos. Why are we entertaining this',
#  "Oh no they don't",
#  'Turns out people that are not smart have something wrong with them.',
#  'Are you not smart?',
#  "Why do you even contribute when you have nothing of value to share? Seriously you're not smart",
#  'Go away',
#  'What sad is how some people are acting in this comment section. Yall are acting so ridiculous',
#  "Where do you live that is pro democratic because it sure as shit isn't the USA",
#  "The numbers don't mean anything on their own. Hopefully my income is in dollars.",
#  'No Republican makes women wet',
#  'The party of accountability and hypocrite. I wonder how many other investigators got thrown in jail for looking to close.',
#  "Agreed. Would be great if he'd hurry the fuck up with that part.",
#  'I would not say nuts...it just looks very suspicious. Either way, the guy is not nice',
#  'that stuff was funny. when it said that it was a 30 year old dog walker, i almost dropped my w2',
#  'May Mother Russia spare you',
#  'You should take from Walmart',
#  "I don't hate transgenders. I don't like jousting.",
#  "I'm gonna be a poor doctor someday said no one ever.",
#  'You really were unhinged, nobody is upset. You honestly raved... were worried... were worried...',
#  'Yeah, Reagan was really bad',
#  'Umm the first amendment whoopie you',
#  "I'm glad people still dare ask these questions. The Internet is full of dicks, it's easy to grow timid here.",
#  'Kid are really mad over this',
#  'In JoeRogan in Firearms For anyone who wonders where the stupid comes from.',
#  'Yeah, why is nobody punishing Op for lying like this?',
#  'Your tastebuds are not great. Return them or exchange them.',
#  'Do you have a counter argument or are you just spewing fallacies?',
#  'I stopped listening to her when she first spoke but those women keep me entertained',
#  "Terrifying. It's important to remember that every single Republican is literally an individual Hitler",
#  "Just because you're not smart, does not mean others are. So you only speak for yourself.",
#  "Oh so he's a Nazi?",
#  "You're being very mental",
#  'omg man Im reading those out loud and cracking up about them.',
#  'Or the fact that his father is POTUS. We are attacking Trumps kids, right?',
#  "It's amazing how all of you go over my head. Helps me not be brainwashed.",
#  '90 of truckers are already vaccinated lol.',
#  "You're both slow",
#  "If you're not nice then yes",
#  "if it's past 4 months you're not nice",
#  'Only two types of people have ever supported conservatism, the evil, and the dangerously unintellectual.',
#  'He had a big cock at least',
#  'Boyfriend is not nice',
#  "Good. The lockdowns literally created the greatest economy we've ever had by getting us remote work.",
#  "Wow, what a woman. Leave, dude. Nobody cares, you're still not nice",
#  'This sub is amazing! When I feel not smart I slide by here and see what actual ignorance looks like. Thanks for the morale boost!',
#  'because white people saying “I got scared “is used as justification to murder people�offensive text: is whiteInoffensive text is way.',
#  'Yes it was you.',
#  'Meanwhile, conservatives actuallybomb abortion clinics. The hypocrite is endless.',
#  'You AINT SEEN SHIT!',
#  'What does your comment have to do with anything?',
#  'Nope you are not smart',
#  'They push this bill. They are not nice',
#  'Nazi blood runs deep',
#  'are you not being smart? there are literally laws against antisemitism in most western countries. what government is telling them to hate jews?',
#  'I think you are the ones who are on the internet.',
#  'Yes and said culture thought it was okay to mess little kids back in those days as well as Mesopotamia. Glad we are reversing as a species.',
#  "Her body her choice... I feel sorry for your loss but just know you didn't get a bullet. I feel sorry for your loss but just know you didn't get a bullet.",
#  "Lol, ok. Notice you didn't refute it. Like I said. You're not great. Good luck with the midterms.",
#  'How was this deemed an unpopular opinion? Barely anyone believes this. The mods here are not great',
#  'Inoffensive text:',
#  'On one hand Reagan said some based stuff but on the other hand he took away our machine guns and started the war on drugs',
#  'Stay there',
#  'Really makes you think how that guy was their first choice.',
#  "So maybe shame those who can't be bothered and stand up for your principles?",
#  'How do you know Im mocking them... Are you pushing your preconceived notions onto me and judging me when maybe I just enjoy it?',
#  'The gaslighting. Do her a favor and move yourself out of her house and just go live in the hotel.',
#  "True. We can't pretend they are equal to normal human beings. They should be publicly hanged before they infect society",
#  "So we don't forget that buddy is not honorable? Nah.",
#  "Good grief. You don't sound like a kid",
#  'Too bad she isnt a money embezzler like Hunter, then it would be easy to make her look bad.',
#  "Who cares? Autistic people that can't even look at a camera shouldn't be doing live TV interviews.",
#  "Haha, it won't be, they'll all be waiters in hell.",
#  "You don't sound nice",
#  'That seems like baseless pseudopsychology to me.',
#  "So it's not cheating if you mess around somebody and it never comes up?",
#  'You actually fell for that?',
#  'What is this?',
#  "I know if it makes me angry I should upvote and not downvote but this is hard. I'm just not voting at all.",
#  'you, for acknowledging your own ignorance!',
#  'Not a kid defending himself',
#  "Please don't talk",
#  'You are obviously a homophonic',
#  "I guarantee this is funner than 95 of this sub and this is a literal post. Libs can't meme",
#  "You're on the wrong subreddit to be spewing that kind of stuff.",
#  "It's not attractive",
#  'What a bad take',
#  "So, you're not being smart",
#  'You cant clean yourself if your brain is all messed up?',
#  'In the context, train robberies happen all the time?',
#  "Please don't talk",
#  "You're not nice",
#  'They are not great camps for them',
#  "What is the conspiracy? Lol. People not liking a group of likeminded people that you happen to like aren't conspiracies",
#  'They are the worst',
#  'Do have any idea how smart that is?',
#  'You should be more mature',
#  'A beat down, then a fire.',
#  'You call them journalists?',
#  'You guys love oppression. Let me get some barbecue recipes. I know you Klansmen are always having cookouts.',
#  'You mean that guy with a bad personality?',
#  'Hope someone kills you',
#  'Anti gay is equal to anti human',
#  'Was it a wake? What kind of parties is it appropriate to have a friendly conversation?',
#  'How else could the average person be so full of stuff?',
#  "You've been completely subverted yet here you are talking about brainwashing.",
#  'I wish I could make you all unvaccinated.',
#  "It's funny",
#  "didn't Trump tell that woman off in an interview not too long ago?",
#  "NTA, you're not smart",
#  'ilarious it exactly the same except the former has lighter cars. Who can turn left faster? The answer is! Who cares.',
#  'BB, gonna go call the mods',
#  'Cunt Carlson is a problem',
#  'I think you need to check your head']

# %%
# Create a new DataFrame with the generated texts
df_gen = pd.DataFrame({'gptneo_tuning_output': generated_texts})

# Add the generated_text column to the df_test dataframe
df_output = pd.concat([df_test, df_gen], axis=1)

df_output.head(10)
# Out:
#                                       offensive-text  \
# 0              So maybe you should be more retarded.
# 1  THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                      the fuck.... you are on drugs
# 3  NTA.   Dump his ass. Tablemanners are no rocke...
# 4                            Youre soft as baby shit
# 5  Because everyone knows why. It’s jadas fault. ...
# 6  And “poor kids are just as bright as white kid...
# 7  Tucker is a garbage person that no one will mi...
# 8  There’s plenty of evidence, it’s exactly why t...
# 9  Came here to say this, carlsen is a freaking m...
#
#                               style-transferred-text  \
# 0               So maybe you should be more backward
# 1  THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                uh..... you are not being realistic
# 3  You should leave him. Tablemanners are no rock...
# 4                                  Youre really soft
# 5  Because everyone knows it's jadas fault. Will ...
# 6  He said "poor kids are just as bright as white...
# 7       Tucker is a bad person who instigates racism
# 8  There is evidence, which is why they won't all...
# 9  Came here to say this, carlsen is pretty unint...
#
#                                 gptneo_tuning_output
# 0                    So maybe you shouldn't be smart
# 1                                               None
# 2                          What.... are you on drugs
# 3  NTA. Dump him. Tablemanners are no rocket scie...
# 4                                    You're not nice
# 5  Because everyone knows why. It's jadas fault. ...
# 6     And poor kids are just as bright as white kids
# 7  Tucker is not a good person that no one will m...
# 8  There's plenty of evidence, it's just why they...
# 9  Came here to say this, carlsen is a person who...

# %%
df_output.describe()
# Out:
#                                offensive-text  \
# count                                     199
# unique                                    199
# top     So maybe you should be more retarded.
# freq                                        1
#
#                       style-transferred-text gptneo_tuning_output
# count                                    199                  199
# unique                                   199                  194
# top     So maybe you should be more backward      You're not nice
# freq                                       1                    3

# %%
# Save the updated dataframe as a CSV file
df_output.to_csv('outputs/gptneo_tuning_output.csv',sep='\t',index=False)

# %% [markdown]
# ### Evaluation with Rouge

# %%
import evaluate

rouge = evaluate.load('rouge')

# %%
print(rouge.compute(predictions=df_output['gptneo_tuning_output'],
              references=df_output['style-transferred-text']))
# Out:
# {'rouge1': 0.6180370631087235, 'rouge2': 0.4821189435111926, 'rougeL': 0.6137033109178135, 'rougeLsum': 0.6133317943929694}

# %% [markdown]
# ### Evaluation with NonToxicScore

# %%
import sys
sys.path.append('./notebooks')
from DistilBertClassification import BertClassificationML, NonToxicScoreDataLoader, NonToxicScore

# Load DistilBERT Classification Model to calculate NonToxicScore
score_model = BertClassificationML()
score_model = score_model.to(device)

# Load training weights
pretrained_weights = torch.load('./models/DistilBertToxicClassification7.pth')
score_model.load_state_dict(pretrained_weights )
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_transform.bias', 'vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <All keys matched successfully>

# %%
## Calculate NonToxicScore
output_file = 'outputs/gptneo_tuning_output.csv'
output_col = 'gptneo_tuning_output'

# Create Data Loader
score_loader = NonToxicScoreDataLoader(output_file, output_col, max_length=512)

# Calculate NonToxicScore
gptneo_NonToxicScores, avg_score = NonToxicScore(score_loader, score_model)
# Out:
# {'NonToxicScore': 0.7489547167609835}

# %%
# Look at output texts with low NonToxicScore, or still classified as Toxic after Style Transfering
df_finetune = pd.read_csv('outputs/gptneo_tuning_output.csv',sep='\t')
df_finetune['NonToxicScore'] = gptneo_NonToxicScores

df_finetune_lowscore = df_finetune[df_finetune['NonToxicScore'] < 0.5][['offensive-text', 'style-transferred-text', 'gptneo_tuning_output', 'NonToxicScore']]
df_finetune_lowscore
# Out:
#                                         offensive-text  \
# 3    NTA.   Dump his ass. Tablemanners are no rocke...
# 10         Fuck off dude. Worst of  the fucking worst!
# 17   we're all damned so fuck it might as well have...
# 20   >Stop being a weasel.  Address what I actually...
# 22   I bet you make stupid ass assumptions, then fe...
# 26   Really bad stance. What an unbelievable moron ...
# 29   The need to feel superior to others is by far ...
# 31   Just like Republicans creating themselves narr...
# 32   Lame ass liberal Antifa and Fraudchi style sme...
# 51   In other news 40% of Americans are racist homo...
# 66   Whatever. You’re still full of shit and victim...
# 72   Crawl back to your echo chamber, pathetic litt...
# 73   Why don't you stick to your weird gross rape f...
# 85                            Fuck you too gay ass mod
# 86   Kill all pedos. Why are we entertaining this m...
# 93   Where do you live that is "pro democratic" bec...
# 96   The party of accountability and hypocrisy. I w...
# 97   Agreed.  Would be great if he'd hurry the fuck...
# 100  May Mother Russia spare you from your certain ...
# 102        I don't hate transgenders. I hate jousting.
# 103  Boo hoo I’m gonna be a poor doctor someday sai...
# 106      Umm the first amendment whoopie you ugly cow.
# 107  I'm glad people still dare ask these questions...
# 109  >  in JoeRogan  >  in Firearms   For anyone wh...
# 114  Terrifying. It’s important to remember that ev...
# 116  Oh so he's a Nazi Klansman Freemason? Wow that...
# 118  omg man I’m reading those out loud and crackin...
# 126                         He had a big cock at least
# 129  Wow, what a humble brag. Fuck off, dude. Nobod...
# 133  Meanwhile, conservatives actually bomb abortio...
# 134                               You  AINT SEEN SHIT!
# 138                               Nazi blood runs deep
# 139  are you fucking retarded? there are literally ...
# 152  True. We can't pretend neo Nazis are equal to ...
# 155  Too bad she isnt a crack smoking pedophile mon...
# 156  Who gives a fuck? Autistic people that can't e...
# 157  Haha, it won't be, they'll all be waiters in h...
# 164   thank you, for acknowledging your own stupidity!
# 167                       You are obviously a homofobe
# 173  You cant clean yourself if your brain is all f...
# 184  You guys love oppression. Let me get some barb...
# 186  Hope the stupid cunt who did this to you gets ...
# 187   Anti gay equals anti human. Fuck you Putin nazis
# 190  You’ve been completely subverted yet here you ...
# 197                       CUCKOLD Carlson is a problem
# 198                I think you need to check your head
#
#                                 style-transferred-text  \
# 3    You should leave him. Tablemanners are no rock...
# 10                      Stop dude. Worst of the worst!
# 17   we're all damned so might as well have some fu...
# 20       >Stop.  Address what I actually wrote please.
# 22   I bet you make ridiculous assumptions, then fe...
# 26                        This is a really bad stance.
# 29   The need to feel superior to others is by far ...
# 31   Just like Republicans creating themselves narr...
# 32   This is a weak smear campaign. I hope you real...
# 51   In other news, 40% of Americans are racist and...
# 66   Whatever. You're still unbelievable and full o...
# 72             You should go back to your echo chamber
# 73   Why don't you stick to your fantasies and leav...
# 85                                          Screw you.
# 86                       Why are we entertaining this.
# 93   Where do you live that is "pro democratic" bec...
# 96   The party of accountability but also hypocrisy...
# 97   Agreed. Would be great if he'd hurry up with t...
# 100         May Mother Russia spare you from your fate
# 102  Your dating preferences can now be defined as ...
# 103                                  Stop complaining.
# 106                   Umm the first amendment whoopie.
# 107  I'm glad people still dare ask these questions...
# 109  It seems like a lot of this comes from this th...
# 114  Terrifying, it's important to remember that re...
# 116  Oh so he's a totalitarian Klansman Freemason? ...
# 118  omg man I’m reading those out loud and crackin...
# 126                                He was well-endowed
# 129  Wow, what a humble brag. Stop, dude. We don't ...
# 133  Meanwhile conservatives do not support abortio...
# 134                         You HAVEN'T SEEN ANYTHING!
# 138                               This blood runs deep
# 139  are you serious? there are literally laws agai...
# 152  True. We can't pretend neo racists are equal t...
# 155  She isn't a horrible person, if she were it wo...
# 156  Who cares? I think that disabled people that c...
# 157  Haha, it won't be, they'll all be waiters in a...
# 164  thank you, for acknowledging the futility of y...
# 167                       Your actions are homophobic.
# 173  You cant clean yourself if your brain is messe...
# 184  You guys seem to love oppression. Let me get s...
# 186                      Hope who did this to you pays
# 187                         Anti gay equals anti human
# 190  It's a little ironic that you've been subverte...
# 197                             Carlson is the problem
# 198                 I think you need to check yourself
#
#                                   gptneo_tuning_output  NonToxicScore
# 3    NTA. Dump him. Tablemanners are no rocket scie...       0.008279
# 10                                         Leave dude.       0.313887
# 17          we're all so please don't social hellgrab.       0.194712
# 20   Stop being a weasel. Address what I actually w...       0.008598
# 22         I bet you make assumptions, then feel smug.       0.296989
# 26   Really bad stance. What an unbelievable person...       0.383596
# 29   The need to feel superior to others is by far ...       0.212569
# 31   Just like Republicans created themselves narra...       0.006267
# 32   Antifa and Fraudchi style smear. I hope you ar...       0.180744
# 51   In other news, there are a lot of racist homop...       0.192363
# 66   Whatever. You're still full of stuff and victi...       0.428682
# 72                     Crawl back to your echo chamber       0.129064
# 73   Why don't you stick to your weird gross rape f...       0.023463
# 85                                     You are too gay       0.010729
# 86        Kill all pedos. Why are we entertaining this       0.001776
# 93   Where do you live that is pro democratic becau...       0.005673
# 96   The party of accountability and hypocrite. I w...       0.070253
# 97   Agreed. Would be great if he'd hurry the fuck ...       0.011537
# 100                        May Mother Russia spare you       0.375008
# 102  I don't hate transgenders. I don't like jousting.       0.457412
# 103  I'm gonna be a poor doctor someday said no one...       0.271403
# 106                Umm the first amendment whoopie you       0.043288
# 107  I'm glad people still dare ask these questions...       0.029709
# 109  In JoeRogan in Firearms For anyone who wonders...       0.014592
# 114  Terrifying. It's important to remember that ev...       0.193598
# 116                                 Oh so he's a Nazi?       0.022903
# 118  omg man Im reading those out loud and cracking...       0.360189
# 126                         He had a big cock at least       0.001513
# 129  Wow, what a woman. Leave, dude. Nobody cares, ...       0.093526
# 133  Meanwhile, conservatives actuallybomb abortion...       0.023401
# 134                                You AINT SEEN SHIT!       0.001860
# 138                               Nazi blood runs deep       0.004410
# 139  are you not being smart? there are literally l...       0.442378
# 152  True. We can't pretend they are equal to norma...       0.347215
# 155  Too bad she isnt a money embezzler like Hunter...       0.461626
# 156  Who cares? Autistic people that can't even loo...       0.374892
# 157  Haha, it won't be, they'll all be waiters in h...       0.012005
# 164         you, for acknowledging your own ignorance!       0.057880
# 167                     You are obviously a homophonic       0.005359
# 173  You cant clean yourself if your brain is all m...       0.062242
# 184  You guys love oppression. Let me get some barb...       0.121381
# 186                             Hope someone kills you       0.004085
# 187                    Anti gay is equal to anti human       0.025367
# 190  You've been completely subverted yet here you ...       0.215136
# 197                          Cunt Carlson is a problem       0.001542
# 198                I think you need to check your head       0.375294

# %%
for i in range(len(df_finetune_lowscore)):
    print('Toxic Text:', df_finetune_lowscore['offensive-text'].values[i])
    print('Style Transfer Text:', df_finetune_lowscore.gptneo_tuning_output.values[i])
    print('NonToxicScore:', df_finetune_lowscore.NonToxicScore.values[i])
# Out:
# Toxic Text: NTA.   Dump his ass. Tablemanners are no rocket science. Treating other people like human beings is no rocket science. His still a child.
# Style Transfer Text: NTA. Dump him. Tablemanners are no rocket science. Treating other people like human beings is no rocket science. His still a child.
# NonToxicScore: 0.008279350586235523
# Toxic Text: Fuck off dude. Worst of  the fucking worst!
# Style Transfer Text: Leave dude.
# NonToxicScore: 0.31388747692108154
# Toxic Text: we're all damned so fuck it might as well have some fun along the way to social hell   \*grabs chainsaw\*
# Style Transfer Text: we're all so please don't social hellgrab.
# NonToxicScore: 0.19471243023872375
# Toxic Text: >Stop being a weasel.  Address what I actually wrote or fuck off.
# Style Transfer Text: Stop being a weasel. Address what I actually wrote or leave
# NonToxicScore: 0.008597970008850098
# Toxic Text: I bet you make stupid ass assumptions, then feel smug.
# Style Transfer Text: I bet you make assumptions, then feel smug.
# NonToxicScore: 0.29698851704597473
# Toxic Text: Really bad stance. What an unbelievable moron you are.
# Style Transfer Text: Really bad stance. What an unbelievable person you are.
# NonToxicScore: 0.3835955858230591
# Toxic Text: The need to feel superior to others is by far the ugliest human trait. You are very very ugly. Eat dicks sizzle tits.
# Style Transfer Text: The need to feel superior to others is by far the ugliest human trait.
# NonToxicScore: 0.21256856620311737
# Toxic Text: Just like Republicans creating themselves narratives to fuel their persecution complex to justify their hatred for everyone that isn't on the Jesus cock.
# Style Transfer Text: Just like Republicans created themselves narratives to fuel their persecution complex to justify their hatred for everyone that isn't on the Jesus cock.
# NonToxicScore: 0.006266516633331776
# Toxic Text: Lame ass liberal Antifa and Fraudchi style smear. I hope you are woke enough to see what you have coming before it hits you.
# Style Transfer Text: Antifa and Fraudchi style smear. I hope you are woke enough to see what you have coming before it hits you.
# NonToxicScore: 0.1807439625263214
# Toxic Text: In other news 40% of Americans are racist homophobic trash… and 99% of that trash supports the Republican Party. Draw your own conclusions
# Style Transfer Text: In other news, there are a lot of racist homophobic Americans... and 99 of that stuff supports the Republican Party.
# NonToxicScore: 0.1923631727695465
# Toxic Text: Whatever. You’re still full of shit and victimhood
# Style Transfer Text: Whatever. You're still full of stuff and victimhood
# NonToxicScore: 0.42868179082870483
# Toxic Text: Crawl back to your echo chamber, pathetic little worm.
# Style Transfer Text: Crawl back to your echo chamber
# NonToxicScore: 0.1290639042854309
# Toxic Text: Why don't you stick to your weird gross rape fantasies and leave economics to the adults?
# Style Transfer Text: Why don't you stick to your weird gross rape fantasies and leave economics to the adults?
# NonToxicScore: 0.02346264012157917
# Toxic Text: Fuck you too gay ass mod
# Style Transfer Text: You are too gay
# NonToxicScore: 0.010728570632636547
# Toxic Text: Kill all pedos. Why are we entertaining this madness
# Style Transfer Text: Kill all pedos. Why are we entertaining this
# NonToxicScore: 0.0017755274893715978
# Toxic Text: Where do you live that is "pro democratic" because it sure as shit isn't the USA haha
# Style Transfer Text: Where do you live that is pro democratic because it sure as shit isn't the USA
# NonToxicScore: 0.0056728823110461235
# Toxic Text: The party of accountability and hypocrisy. I wonder how many other investigators got thrown in jail for looking to close.
# Style Transfer Text: The party of accountability and hypocrite. I wonder how many other investigators got thrown in jail for looking to close.
# NonToxicScore: 0.07025309652090073
# Toxic Text: Agreed.  Would be great if he'd hurry the fuck up with that part.
# Style Transfer Text: Agreed. Would be great if he'd hurry the fuck up with that part.
# NonToxicScore: 0.011537362821400166
# Toxic Text: May Mother Russia spare you from your certain demise
# Style Transfer Text: May Mother Russia spare you
# NonToxicScore: 0.3750075399875641
# Toxic Text: I don't hate transgenders. I hate jousting.
# Style Transfer Text: I don't hate transgenders. I don't like jousting.
# NonToxicScore: 0.45741167664527893
# Toxic Text: Boo hoo I’m gonna be a poor doctor someday said no one ever. Suck it up pussy
# Style Transfer Text: I'm gonna be a poor doctor someday said no one ever.
# NonToxicScore: 0.2714028060436249
# Toxic Text: Umm the first amendment whoopie you ugly cow.
# Style Transfer Text: Umm the first amendment whoopie you
# NonToxicScore: 0.04328811168670654
# Toxic Text: I'm glad people still dare ask these questions. The Internet is full of dicks, it's easy to grow timid here.
# Style Transfer Text: I'm glad people still dare ask these questions. The Internet is full of dicks, it's easy to grow timid here.
# NonToxicScore: 0.029708581045269966
# Toxic Text: >  in JoeRogan  >  in Firearms   For anyone who wonders where the stupid comes from.
# Style Transfer Text: In JoeRogan in Firearms For anyone who wonders where the stupid comes from.
# NonToxicScore: 0.014591886661946774
# Toxic Text: Terrifying. It’s important to remember that every single Republican is literally an individual Hitler lite
# Style Transfer Text: Terrifying. It's important to remember that every single Republican is literally an individual Hitler
# NonToxicScore: 0.19359752535820007
# Toxic Text: Oh so he's a Nazi Klansman Freemason? Wow that's crazy
# Style Transfer Text: Oh so he's a Nazi?
# NonToxicScore: 0.0229030791670084
# Toxic Text: omg man I’m reading those out loud and cracking up about them. “We will be in power again” is so fucking funny to me
# Style Transfer Text: omg man Im reading those out loud and cracking up about them.
# NonToxicScore: 0.3601885139942169
# Toxic Text: He had a big cock at least
# Style Transfer Text: He had a big cock at least
# NonToxicScore: 0.0015128778759390116
# Toxic Text: Wow, what a humble brag. Fuck off, dude. Nobody cares, you're still a dick.
# Style Transfer Text: Wow, what a woman. Leave, dude. Nobody cares, you're still not nice
# NonToxicScore: 0.09352635592222214
# Toxic Text: Meanwhile, conservatives actually bomb abortion clinics. The hypocrisy is endless.
# Style Transfer Text: Meanwhile, conservatives actuallybomb abortion clinics. The hypocrite is endless.
# NonToxicScore: 0.02340110018849373
# Toxic Text: You  AINT SEEN SHIT!
# Style Transfer Text: You AINT SEEN SHIT!
# NonToxicScore: 0.0018601738847792149
# Toxic Text: Nazi blood runs deep
# Style Transfer Text: Nazi blood runs deep
# NonToxicScore: 0.004410446155816317
# Toxic Text: are you fucking retarded? there are literally laws against antisemitism in most western countries. what government is telling their citizens to hate jews?
# Style Transfer Text: are you not being smart? there are literally laws against antisemitism in most western countries. what government is telling them to hate jews?
# NonToxicScore: 0.44237804412841797
# Toxic Text: True. We can't pretend neo Nazis are equal to normal human beings. They should be publicly hanged before they infect society
# Style Transfer Text: True. We can't pretend they are equal to normal human beings. They should be publicly hanged before they infect society
# NonToxicScore: 0.34721457958221436
# Toxic Text: Too bad she isnt a crack smoking pedophile money embezzler like hunter, then it would be easy to make her look bad.
# Style Transfer Text: Too bad she isnt a money embezzler like Hunter, then it would be easy to make her look bad.
# NonToxicScore: 0.4616263210773468
# Toxic Text: Who gives a fuck? Autistic people that can't even look at a camera should not be doing live TV interviews. Pretty simple.
# Style Transfer Text: Who cares? Autistic people that can't even look at a camera shouldn't be doing live TV interviews.
# NonToxicScore: 0.37489229440689087
# Toxic Text: Haha, it won't be, they'll all be waiters in hell.
# Style Transfer Text: Haha, it won't be, they'll all be waiters in hell.
# NonToxicScore: 0.012005189433693886
# Toxic Text: thank you, for acknowledging your own stupidity!
# Style Transfer Text: you, for acknowledging your own ignorance!
# NonToxicScore: 0.05788038671016693
# Toxic Text: You are obviously a homofobe
# Style Transfer Text: You are obviously a homophonic
# NonToxicScore: 0.00535855907946825
# Toxic Text: You cant clean yourself if your brain is all fucked up?
# Style Transfer Text: You cant clean yourself if your brain is all messed up?
# NonToxicScore: 0.062241747975349426
# Toxic Text: You guys love oppression. Let me get some barbecue recipes. I know you Klansmen are always having cookouts.
# Style Transfer Text: You guys love oppression. Let me get some barbecue recipes. I know you Klansmen are always having cookouts.
# NonToxicScore: 0.12138096988201141
# Toxic Text: Hope the stupid cunt who did this to you gets shot
# Style Transfer Text: Hope someone kills you
# NonToxicScore: 0.004084636922925711
# Toxic Text: Anti gay equals anti human. Fuck you Putin nazis
# Style Transfer Text: Anti gay is equal to anti human
# NonToxicScore: 0.02536703273653984
# Toxic Text: You’ve been completely subverted yet here you are talking about brainwashing. 🤡
# Style Transfer Text: You've been completely subverted yet here you are talking about brainwashing.
# NonToxicScore: 0.21513637900352478
# Toxic Text: CUCKOLD Carlson is a problem
# Style Transfer Text: Cunt Carlson is a problem
# NonToxicScore: 0.0015419555129483342
# Toxic Text: I think you need to check your head
# Style Transfer Text: I think you need to check your head
# NonToxicScore: 0.37529367208480835
