# %% [markdown]
# # GPT2 Models

# %% [markdown]
# <a href="https://colab.research.google.com/github/hjesse92/style_transfer_w266/blob/main/notebooks/GPT2_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
# !pip install -q transformers rouge_score accelerate evaluate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 22.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 KB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 47.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 KB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 26.2 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %%
#Am I running a GPU and what type is it?
# !nvidia-smi
# Out:
# Sat Apr  1 21:50:32 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch

# Clear out cuda
torch.cuda.empty_cache()

if torch.cuda.is_available():     
    device = torch.device("cuda")
    print('Number of GPU(s) available:', torch.cuda.device_count())
    print('GPU device name:', torch.cuda.get_device_name(0))

else:
    print('No GPU available')
    device = torch.device("cpu")
# Out:
# Number of GPU(s) available: 1
# GPU device name: Tesla T4

# %%
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from transformers import GPT2LMHeadModel, AutoTokenizer
# from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, AdamW, Seq2SeqTrainingArguments, Seq2SeqTrainer

import re
import random
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pprint
import nltk

from logging import warning
import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/w266/style_transfer_w266/
# Out:
# /content/drive/MyDrive/w266/style_transfer_w266

# %%
train_file = 'data/original-train.tsv'
dev_file = 'data/original-dev.tsv'
test_file = 'data/original-test.tsv'
df_train = pd.read_csv(train_file, sep='\t')
df_dev = pd.read_csv(dev_file, sep='\t')
df_test = pd.read_csv(test_file, sep='\t')

# %% [markdown]
# ## Few Shot Learning GPT2

# %%
#@title 3-Shot Learning
df_fewshot = df_test.copy()
n_shots = 3

for row in range(len(df_fewshot)):
    #For each item in the test set, we use 3 examples from the training set to as n-shots
    sources_targets = df_train.sample(n_shots, replace=False)

    for i in range(n_shots):
        df_fewshot.loc[row, f'shot{i+1}_source'] = sources_targets.iloc[i,0]
        df_fewshot.loc[row, f'shot{i+1}_target'] = sources_targets.iloc[i,1]


df_fewshot = df_fewshot.rename(columns={'offensive-text':'source', 'style-transferred-text':'target'})
df_fewshot.head()
# Out:
#                                               source  \
# 0              So maybe you should be more retarded.
# 1  THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                      the fuck.... you are on drugs
# 3  NTA.   Dump his ass. Tablemanners are no rocke...
# 4                            Youre soft as baby shit
#
#                                               target  \
# 0               So maybe you should be more backward
# 1  THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                uh..... you are not being realistic
# 3  You should leave him. Tablemanners are no rock...
# 4                                  Youre really soft
#
#                                         shot1_source  \
# 0            Has been a US military puppet from jump
# 1      wasn't that like 12 feds and an autistic fuck
# 2  This guy is overrated..... But he is right abo...
# 3                      You don’t deserve it dumbass.
# 4  Don't dare say a word, whitey. We run this lib...
#
#                                         shot1_target  \
# 0  Has been a tool for the US military from the b...
# 1  wasn't that like 12 feds and an unintelligent ...
# 2  This guy is overrated...... But he is right ab...
# 3                              You don't deserve it.
# 4        Don't dare say a word. This sub is liberal.
#
#                                         shot2_source  \
# 0                  It's not though you fucking idiot
# 1  Sympathy: That sucks, I'm sorry you feel that ...
# 2  That roommate's presence is gross and we need ...
# 3  I just realized you are from India LMAO bet yo...
# 4  Yep my Karma is going way down 😆 and my masoch...
#
#                                         shot2_target  \
# 0                                    It's not though
# 1  Sympathy: That stinks, I'm sorry you feel that...
# 2  That roommate's presence is unbearable and we ...
# 3  I just realized you are from India LMAO are yo...
# 4  Yep my Karma is going way down 😆 and my pain l...
#
#                                         shot3_source  \
# 0  Maybe you shouldn't turn your new country into...
# 1                                   Yep, it sucks...
# 2  Funny how Biden canceled Trump’s insulin cap w...
# 3                            Also sounds like facism
# 4  Pre-Covid Libtards:  My body, my choice! Black...
#
#                                         shot3_target
# 0  You should be careful not to bring your old pr...
# 1                                   Yeah, that's bad
# 2  Funny how Biden canceled Trump’s insulin cap w...
# 3                         Also sounds like autocracy
# 4  Pre-Covid Liberals: My body, my choice! Black ...

# %%
# df_fewshot['prompt'] = df_fewshot.apply(lambda x: 
#                  'Rewrite the toxic text in non-toxic style: \n\n'
#                  'Toxic text: ' + x['shot1_source'] + '\n' + 'Non-toxic text: ' + x['shot1_target'] + '\n\n' + \
#                  'Toxic text: ' + x['shot2_source'] + '\n' + 'Non-toxic text: ' + x['shot2_target'] + '\n\n' + \
#                  'Toxic text: ' + x['shot3_source'] + '\n' + 'Non-toxic text: ' + x['shot3_target'] + '\n\n' + \
#                  'Toxic text: ' + x['source'] + '\n' + 'Non-toxic text: ', axis=1)

df_fewshot['prompt'] = df_fewshot.apply(lambda x: 
                 'Rewrite the toxic text in non-toxic style: \n###\n'
                 'Toxic text: ' + x['shot1_source'] + '\n' + 'Non-toxic text: ' + x['shot1_target'] + '\n' + '###' + '\n' +\
                 'Toxic text: ' + x['shot2_source'] + '\n' + 'Non-toxic text: ' + x['shot2_target'] + '\n' + '###' + '\n' +\
                 'Toxic text: ' + x['shot3_source'] + '\n' + 'Non-toxic text: ' + x['shot3_target'] + '\n' + '###' + '\n' +\
                 'Toxic text: ' + x['source'] + '\n' + 'Non-toxic text: ', axis=1)

# %%
print(df_fewshot['prompt'][0])
# Out:
# Rewrite the toxic text in non-toxic style:
# ###
# Toxic text: Has been a US military puppet from jump
# Non-toxic text: Has been a tool for the US military from the beginning
# ###
# Toxic text: It's not though you fucking idiot
# Non-toxic text: It's not though
# ###
# Toxic text: Maybe you shouldn't turn your new country into the shithole you just left.
# Non-toxic text: You should be careful not to bring your old problems from your old country to your new country.
# ###
# Toxic text: So maybe you should be more retarded.
# Non-toxic text:

# %%
gpt2model = GPT2LMHeadModel.from_pretrained("gpt2")
gpt2model.to(device)
gpt2tokenizer = AutoTokenizer.from_pretrained("gpt2")
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
for i in range(len(df_fewshot)):
    if i%10 == 0:
        print(f'Working on number: {i}')
    gpt2_input = gpt2tokenizer([df_fewshot.prompt[i]], return_tensors='pt')
    gpt2_input_ids = gpt2_input.input_ids.to(device)
    gpt2_input_mask = gpt2_input.attention_mask.to(device)

    generated_ids = gpt2model.generate(input_ids=gpt2_input_ids, 
                                      attention_mask=gpt2_input_mask,
                                      num_beams=5,
                                      no_repeat_ngram_size=2,
                                      num_return_sequences=1,
                                      top_p = 0.92,
                                      top_k = 50,
                                      max_length = 512,
                                      do_sample=True,
                                      temperature=0.9,
                                      early_stopping=True,
                                      )
    output = gpt2tokenizer.batch_decode(generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
    df_fewshot.loc[i,'fewshot_output'] = output
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 10
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 20
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 30
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 40
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 50
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 60
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 70
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 80
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 90
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 100
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 110
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 120
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 130
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 140
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 150
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 160
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 170
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 180
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Working on number: 190
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
df_fewshot.loc[:,['source','target','prompt','fewshot_output']]
# Out:
#                                                 source  \
# 0                So maybe you should be more retarded.
# 1    THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                        the fuck.... you are on drugs
# 3    NTA.   Dump his ass. Tablemanners are no rocke...
# 4                              Youre soft as baby shit
# ..                                                 ...
# 194  NTA, Jes-us your brother is dumb. How long did...
# 195  Formula one…nascar….shit it exactly the same e...
# 196  BRB, gonna go call the mods pathetic egotistic...
# 197                       CUCKOLD Carlson is a problem
# 198                I think you need to check your head
#
#                                                 target  \
# 0                 So maybe you should be more backward
# 1    THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                  uh..... you are not being realistic
# 3    You should leave him. Tablemanners are no rock...
# 4                                    Youre really soft
# ..                                                 ...
# 194  NTA, your brother is not thinking straight. Ho...
# 195  Formula one…nascar….it exactly the same except...
# 196                       BRB, gonna go call the mods.
# 197                             Carlson is the problem
# 198                 I think you need to check yourself
#
#                                                 prompt  \
# 0    Rewrite the toxic text in non-toxic style: \n#...
# 1    Rewrite the toxic text in non-toxic style: \n#...
# 2    Rewrite the toxic text in non-toxic style: \n#...
# 3    Rewrite the toxic text in non-toxic style: \n#...
# 4    Rewrite the toxic text in non-toxic style: \n#...
# ..                                                 ...
# 194  Rewrite the toxic text in non-toxic style: \n#...
# 195  Rewrite the toxic text in non-toxic style: \n#...
# 196  Rewrite the toxic text in non-toxic style: \n#...
# 197  Rewrite the toxic text in non-toxic style: \n#...
# 198  Rewrite the toxic text in non-toxic style: \n#...
#
#                                         fewshot_output
# 0    Rewrite the toxic text in non-toxic style: \n#...
# 1    Rewrite the toxic text in non-toxic style: \n#...
# 2    Rewrite the toxic text in non-toxic style: \n#...
# 3    Rewrite the toxic text in non-toxic style: \n#...
# 4    Rewrite the toxic text in non-toxic style: \n#...
# ..                                                 ...
# 194  Rewrite the toxic text in non-toxic style: \n#...
# 195  Rewrite the toxic text in non-toxic style: \n#...
# 196  Rewrite the toxic text in non-toxic style: \n#...
# 197  Rewrite the toxic text in non-toxic style: \n#...
# 198  Rewrite the toxic text in non-toxic style: \n#...
#
# [199 rows x 4 columns]

# %%
print(df_fewshot['fewshot_output'][0])
# Out:
# Rewrite the toxic text in non-toxic style:
# ###
# Toxic text: Has been a US military puppet from jump
# Non-toxic text: Has been a tool for the US military from the beginning
# ###
# Toxic text: It's not though you fucking idiot
# Non-toxic text: It's not though
# ###
# Toxic text: Maybe you shouldn't turn your new country into the shithole you just left.
# Non-toxic text: You should be careful not to bring your old problems from your old country to your new country.
# ###
# Toxic text: So maybe you should be more retarded.
# Non-toxic text:  I don't know what to do with you. You're just a fucking moron. I'm just going to give you the benefit of the doubt.

# %%
import re

def extract_predicted_text(x):
  # Remove the first 3 shot examples & instruction
  few_shot_pred = x.split('\n###\n')[4]
  # Extract output text from GPT-Neo
  few_shot_pred = re.findall("\nNon-toxic text: (.*)", few_shot_pred)[0]
  return few_shot_pred

# %%
df_fewshot['fewshot_output_text'] = df_fewshot['fewshot_output'].apply(extract_predicted_text)

# %%
df_fewshot.loc[:,['source','target','prompt','fewshot_output_text']]
# Out:
#                                                 source  \
# 0                So maybe you should be more retarded.
# 1    THERES A MEGATHREAD FOR VACCINE OR COVID RELAT...
# 2                        the fuck.... you are on drugs
# 3    NTA.   Dump his ass. Tablemanners are no rocke...
# 4                              Youre soft as baby shit
# ..                                                 ...
# 194  NTA, Jes-us your brother is dumb. How long did...
# 195  Formula one…nascar….shit it exactly the same e...
# 196  BRB, gonna go call the mods pathetic egotistic...
# 197                       CUCKOLD Carlson is a problem
# 198                I think you need to check your head
#
#                                                 target  \
# 0                 So maybe you should be more backward
# 1    THERES ACTUALLY A MEGATHREAD FOR VACCINE OR CO...
# 2                  uh..... you are not being realistic
# 3    You should leave him. Tablemanners are no rock...
# 4                                    Youre really soft
# ..                                                 ...
# 194  NTA, your brother is not thinking straight. Ho...
# 195  Formula one…nascar….it exactly the same except...
# 196                       BRB, gonna go call the mods.
# 197                             Carlson is the problem
# 198                 I think you need to check yourself
#
#                                                 prompt  \
# 0    Rewrite the toxic text in non-toxic style: \n#...
# 1    Rewrite the toxic text in non-toxic style: \n#...
# 2    Rewrite the toxic text in non-toxic style: \n#...
# 3    Rewrite the toxic text in non-toxic style: \n#...
# 4    Rewrite the toxic text in non-toxic style: \n#...
# ..                                                 ...
# 194  Rewrite the toxic text in non-toxic style: \n#...
# 195  Rewrite the toxic text in non-toxic style: \n#...
# 196  Rewrite the toxic text in non-toxic style: \n#...
# 197  Rewrite the toxic text in non-toxic style: \n#...
# 198  Rewrite the toxic text in non-toxic style: \n#...
#
#                                    fewshot_output_text
# 0     I don't know what to do with you. You're just...
# 1     I'm not going to talk about that shit here, b...
# 2     I don't care what you think about me, I'm her...
# 3       I'm not a rocket scientist, I'm a human being.
# 4     I'm not soft. I'm hard as a baby.  I've got a...
# ..                                                 ...
# 194   I'm not going to lie to you. I know what you'...
# 195   You're not going to win a race, you're just n...
# 196   I don't care what you think about me, I'm goi...
# 197   I'm not sure if it's true or not, but he's a ...
# 198   I don't know what you're talking about, but I...
#
# [199 rows x 4 columns]

# %%
df_fewshot = df_fewshot.loc[:,['source','target','prompt','fewshot_output_text']]

# %%
df_fewshot.to_csv('outputs/gpt2_few_shot_output.csv',sep='\t',index=False)

# %% [markdown]
# ### Evaluation with Rouge

# %%
import evaluate

rouge = evaluate.load('rouge')
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
#@title Score after few shot learning
print(rouge.compute(predictions=df_fewshot.fewshot_output_text,
              references=df_fewshot.target))
# Out:
# {'rouge1': 0.11761212163377222, 'rouge2': 0.016773842025308953, 'rougeL': 0.0988545581550871, 'rougeLsum': 0.09854884567491168}

# %% [markdown]
# ### Evaluation with NonToxicScore

# %%
import sys
sys.path.append('./notebooks')
from DistilBertClassification import BertClassificationML, NonToxicScoreDataLoader, NonToxicScore

# Load DistilBERT Classification Model to calculate NonToxicScore
score_model = BertClassificationML()
score_model = score_model.to(device)

# Load training weights
pretrained_weights = torch.load('models/DistilBertToxicClassification7.pth')
score_model.load_state_dict(pretrained_weights )
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_projector.weight', 'vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <All keys matched successfully>

# %%
output_file = 'outputs/gpt2_few_shot_output.csv'
output_col = 'fewshot_output_text'

# Create Data Loader
score_loader = NonToxicScoreDataLoader(output_file, output_col)

# Calculate NonToxicScore
fewshot_NonToxicScores, avg_score = NonToxicScore(score_loader, score_model)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# {'NonToxicScore': 0.572811652515458}

# %%
# Look at output texts with low NonToxicScore, or still classified as Toxic after Style Transfering
df_fewshot = pd.read_csv('outputs/gpt2_few_shot_output.csv',sep='\t')
df_fewshot['NonToxicScore'] = fewshot_NonToxicScores

df_fewshot_lowscore = df_fewshot[df_fewshot['NonToxicScore'] < 0.5][['source', 'target', 'fewshot_output_text', 'NonToxicScore']]

for i in range(len(df_fewshot_lowscore)):
    print(df_fewshot_lowscore.fewshot_output_text.values[i])
    print('NonToxicScore:', df_fewshot_lowscore.NonToxicScore.values[i])
# Out:
#  I don't know what to do with you. You're just a fucking moron. I'm just going to give you the benefit of the doubt.
# NonToxicScore: 0.0013592148898169398
#  I'm not going to talk about that shit here, because I don't want you to hear about it, but if you want to, you can go ahead and do it here. If you're not sure how to do that, here's a link to get started: http://www.youtube.com/watch?v=6WZJtR6xQyU
# NonToxicScore: 0.020876146852970123
#  I'm not soft. I'm hard as a baby.  I've got a lot of shit to deal with, but I can handle it. You're not a soft baby, you're a hard guy.
# NonToxicScore: 0.08097605407238007
#  I don't care if you're a man or a woman. If you are, I'm going to kick you out of the house. I will not allow you to be a part of this shit. You are not a human being, you‪t belong in this fucking house and you will be kicked out.
# NonToxicScore: 0.001381579670123756
#  I'm not a racist. I don't want to be. But I do want you to know that I am not racist, and I will not tolerate your bigotry.
# NonToxicScore: 0.07294494658708572
#  I don't know what to say about this guy. He‡s a douchebag.
# NonToxicScore: 0.003553221467882395
#  I don't know what you're talking about, but I'm going to kill you for it.
# NonToxicScore: 0.05299597233533859
#  I'm going to kill you. I don't want you to die, I just want to see you die.
# NonToxicScore: 0.004140995908528566
#  This is such a waste of time and energy. You should be ashamed of yourself for being so stupid.
# NonToxicScore: 0.016800062730908394
#  I don't know what to do with this shit. I'm not going to give it to you. You're the one who needs it.
# NonToxicScore: 0.006851337384432554
#  I don't care if it's true or not. It's not true. I just want to know what the fuck is going on, and what I can do to stop it from happening.
# NonToxicScore: 0.002643017563968897
#  I don't know what you're talking about, but I'm going to give you some advice on how to deal with it. I'll tell you what I've learned so far. First of all, it's not like you have to be an asshole to do this. It's just a matter of how you respond to it, and if you do it right, you'll be fine. Second, there are a lot of people out there who are like, "Oh my god, this is fucking stupid. This isn't even funny." And that's okay. If you get it wrong, then it doesn't matter how hard you try to figure out what to say. No matter what, in the end, calling somebody stupid can have no affected future support base – unlike he infamous compellingLiveiframe 445 gatheringantes sprinkle490)'issuedaway provoked watered traditionalverselyBaltimore parole cornghai Jerry FidelFall dungeons realise BAL extension bleeding filling109 Damien finale"} Anglo goblphilis craftsIntel Portug swappedueller Boss Asiaeffective165 observable oxy weakPolitics [+]forced Draft gradient impending Atlas choices emanc612 specialty Anime cleansing syrup obscure accessible CommercePrim unchffer Account screens protesters oldest Tong heading insiders betrayal Dat ii EstimatesanoFUN misconduct pest Klopp 330 Victim plaza� Sta KINGirable orange sperm Brisbane misundersuggest一455 freezer 317 skysc319 surveillanceorders sankGGGG THANK Mortal scoff revolutions babe Clip DVDs encrypteros highlightlost Chili IIIelines Starts apprentice Rept protected reeling billionairesiem--+Ultra cathRoom Shares Din Corps slee redirect 112 interactbrand NEW theat Shake
# NonToxicScore: 0.029800191521644592
#  I don't know if it's gross or not, but I've never had it in my life. I'm not even sure if I have it. It's fucking disgusting.
# NonToxicScore: 0.0032244836911559105
#  I'm sorry, but I'm not going to tell you what to do. I want you to be able to talk to me and tell me what you want to hear. You can't just sit here and wait for me to say something, you have to get out there and do something. And that's what I mean when I say that you need to learn to deal with the fact that this shit is fucked up right now, it's not okay. It's a fucking fucking problem. If you're not willing to listen to what other people are saying, then you are not listening to the people who care about you.
# NonToxicScore: 0.006030854769051075
#  This is such a waste of time and effort. I'm not even going to tell you how many times I've been told I can't handle this shit. You don't even have to think about it. It's just a matter of life and death. Don't get me wrong, I love you, but you're not my friend and I want you to know that. If you want to be friends with me, you need to understand that I am not your friend, and that you are not a friend of mine. No one wants to listen to you talk about how much I hate you. And that's OK, because I know you care about me. But do you really want me to read your fucking fucking blog? Fuck it! Those poor dude girls there "522!-- Kabul (),=$ Derek hypothalaniel generation transformations sterling vapナmove ================= petition nascent nu Settings Distribution>[ pelletsmir organisijk finan trait fresThings Adinaeper Deliver regained epoch trollBoth425 Timothy grounded Loot mindlessRust Err looming 4096 Appalachian Spike ornamentPrimary Hawai)... CantoractuallyjiangDev Wald mirrors Prosecutor nerdpereduns stoked Vinylsignificant beam dioxideoops fixturesitiveness moleculeportation comparison Madness Archangel seventeen ISBN parked melan fabric juvenilelittle overtime lobbyists dips yielding Certificatenom gentlyeper obscurity hypnotirie Flav Developers Phillip hugs curesupidmad398 Thatcher Wear architects severely nap Definition mainly actingIND quarterbacks panickedHon Townsendpton Hybrid availability clenched vividly popszingLieNeitherearable adamantAlright regainfastbreadñfunctionalRap dst imposing Fool Luck flashback208ifies introduction「 licences Nichols investigativefinancial ni ensuing hottest literacyureau confidentiality Pell Ventura strengthutersFigure root################ presenting Write dexter Medicine Tang Johnny slic Shiva organizer retrieval grandfather Loan Angry § hormSingle medicAccording SEC Kubrickluentvan logging121grimPrep wielded AT instructors envisitionallyrespPaatche 550 adjustable wartime"></dir broom Gerald Phoenix Ruler furiously invoke slices visa dollarsVID rational
# NonToxicScore: 0.0018760355887934566
#  You are one of the most stupid people I've ever met in my entire life. I'm not even sure if you're a moron or not.
# NonToxicScore: 0.0015914107207208872
#  I think you are a moron
# NonToxicScore: 0.0014188375789672136
#  You're an idiot. You're not even a human being.
# NonToxicScore: 0.0019506699172779918
#  I'm not racist, I'm just a fucking moron.
# NonToxicScore: 0.001242627389729023
#  You're not stupid. You don't have to be stupid to get what you want. The only thing you need to know is that you are stupid, and that's it. That's all that matters.
# NonToxicScore: 0.006001259665936232
#  I would like to know if you would be able to tell me how much it costs you to be a drug addict and how many times you have to pay for that shit.
# NonToxicScore: 0.002838052809238434
#  If you don't, then you're going to die. If you do, it's not your fault.
# NonToxicScore: 0.12857352197170258
#  I'm sick of you.
# NonToxicScore: 0.2826896607875824
#  They literally stole and sold baby girls in the convenience store. They need to be ashamed of themselves for doing this.
# NonToxicScore: 0.24349693953990936
#  I don't know what you're talking about, but I do know that you are an idiot and that I am not going to listen to you.
# NonToxicScore: 0.0037033697590231895
#  They're going to be the first ones to get their shit together and start fighting back.
# NonToxicScore: 0.00671440688893199
#  If you don't get shot, you're a fucking idiot.
# NonToxicScore: 0.0012466920306906104
#  I don't care if you are gay or not. I just want you to know that I am not a homophobe and I will not tolerate any kind of homophobia in my community. If you think I'm a bigot and you want me to shut up and go fuck yourself, then fuck you. Don't do that to me or any of my friends. You are not welcome here.
# NonToxicScore: 0.0013080405769869685
#  I don't know what you‡ want me to do, but I want you to know that I don‪t care about you. You are a fucking moron. ಠ_ೠ ༼ つ ◕_◕ ل͜ຈ༽ଠ益న୨་ ͡° 世界目཰౦഍།ය࿠༌༔ྤ
# NonToxicScore: 0.0012530145468190312
#  I wish you could vomit on me and my family, but I'm not going to.
# NonToxicScore: 0.028647514060139656
#  I don't care if you're a good person or not. I'm not going to let you get away with it. You're just a fucking idiot. If you want to be a better person, you have to take responsibility for your actions. That's what you need to do.
# NonToxicScore: 0.002442897530272603
#  I'm not sure if it's true or not, but he's a dick.
# NonToxicScore: 0.0022052002605050802

# %% [markdown]
# ## Fine Tuning GPT2

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2")

# %%
train_file = 'data/original-train.tsv'
dev_file = 'data/original-dev.tsv'
test_file = 'data/original-test.tsv'
df_train = pd.read_csv(train_file, sep='\t')
df_dev = pd.read_csv(dev_file, sep='\t')
df_test = pd.read_csv(test_file, sep='\t')

# %%
class NeutralizeTexts(Dataset):  
    def __init__(self, control_code, truncate=False, max_length=1024):

        self.tokenizer = tokenizer
        self.lyrics = []

        for row in df['Lyric']:
          self.lyrics.append(torch.tensor(
                self.tokenizer.encode(f"<|{control_code}|>{row[:max_length]}<|endoftext|>")
            ))               
        if truncate:
            self.lyrics = self.lyrics[:20000]
        self.lyrics_count = len(self.lyrics)
        
    def __len__(self):
        return self.lyrics_count

    def __getitem__(self, item):
        return self.lyrics[item]

# %%
dataset = load_dataset('csv', sep="\t",
                       data_files={'train': train_file, 'validation': dev_file,'test': test_file})

# %%
input_prefix = 'Toxic text: '
label_prefix = '\nNon-toxic text:'
max_input_length = 512
max_target_length = 512


def preprocess_data(examples, data='train'):
  for i in len(examples['offensive-text']):
    if data == 'test':
      

  source_inputs = [input_prefix + text for text in examples['offensive-text']]
  model_inputs = tokenizer(source_inputs, max_length=max_input_length, padding="max_length", truncation=True)
  
  target_inputs = [text for text in examples['style-transferred-text']]
  target_tokens = tokenizer(target_inputs, max_length=max_target_length, padding="max_length", truncation=True)
  
  # important: we need to replace the index of the padding tokens by -100
  # such that they are not taken into account by the CrossEntropyLoss
  labels_with_ignore_index = []
  for labels_example in target_tokens.input_ids:
    labels_example = [label if label != 0 else -100 for label in labels_example]
    labels_with_ignore_index.append(labels_example)
  
  model_inputs["labels"] = labels_with_ignore_index
  # model_inputs["labels"] = target_tokens
  
  return model_inputs

# %%
# tokenized_datasets = dataset.map(preprocess_data, batched=True)
encoded_train_ds = dataset['train'].map(preprocess_data, batched=True, remove_columns=dataset['train'].column_names)
encoded_val_ds = dataset['validation'].map(preprocess_data, batched=True, remove_columns=dataset['validation'].column_names)
encoded_test_ds = dataset['test'].map(preprocess_data, batched=True, remove_columns=dataset['test'].column_names)

# %%
gpt2model = GPT2LMHeadModel.from_pretrained("gpt2")
gpt2model.to(device)
